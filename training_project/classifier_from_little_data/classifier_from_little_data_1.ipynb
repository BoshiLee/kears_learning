# %% [markdown]
# It uses data that can be downloaded at:
# https://www.kaggle.com/c/dogs-vs-cats/data
# In our setup, we:
# - created a data/ folder
# - created train/ and validation/ subfolders inside data/
# - created cats/ and dogs/ subfolders inside train/ and validation/
# - put the cat pictures index 0-999 in data/train/cats
# - put the cat pictures index 1000-1399 in data/validation/cats
# - put the dogs pictures index 0-999 in data/train/dogs
# - put the dog pictures index 1000-1399 in data/validation/dogs
# So that we have 1000 training examples for each class, and 400 validation examples for each class.
# In summary, this is our directory structure:
# ```
# data/
#     train/
#
#         cats/
#             cat.0.jpg
#             cat.1.jpg
#             ...
#         dogs/
#             dog.0.jpg
#             dog.1.jpg
#             ...
#     validation/
#         cats/
#             cat.1000.jpg
#             cat.1001.jpg
#             ...
#         dogs/
#             dog.1000.jpg
#             dog.1001.jpg
#             ...

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K

# %%
is_gpu = len(tf.config.list_physical_devices('GPU')) > 0
is_gpu
# Out:
# True

# %%
# dimensions of our images.
img_width, img_height = 150, 150

train_data_dir = 'data/train'
validation_data_dir = 'data/validation'
nb_train_samples = 2000
nb_validation_samples = 800
epochs = 50
batch_size = 16

if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)



# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 23000 images belonging to 2 classes.

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %% [markdown]
# 假如出現錯誤:
#
# ImportError('Could not import PIL.Image. ' working with keras-ternsorflow
#
# conda install pillow
#
# ImportError('Image transformations require SciPy.
#
# conda install -c anaconda scipy

# %%
model.fit(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)

model.save('first_try.h5')
# Out:
# Epoch 1/50
# 125/125 [==============================] - 13s 82ms/step - loss: 0.7121 - accuracy: 0.5420 - val_loss: 0.6782 - val_accuracy: 0.6062
# Epoch 2/50
# 125/125 [==============================] - 10s 80ms/step - loss: 0.6798 - accuracy: 0.6305 - val_loss: 0.6186 - val_accuracy: 0.6325
# Epoch 3/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.6482 - accuracy: 0.6325 - val_loss: 0.6194 - val_accuracy: 0.6687
# Epoch 4/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.6120 - accuracy: 0.6760 - val_loss: 0.5758 - val_accuracy: 0.6862
# Epoch 5/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.5833 - accuracy: 0.6930 - val_loss: 0.5779 - val_accuracy: 0.7050
# Epoch 6/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.5688 - accuracy: 0.7210 - val_loss: 0.6118 - val_accuracy: 0.6900
# Epoch 7/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.5587 - accuracy: 0.7180 - val_loss: 0.5370 - val_accuracy: 0.7588
# Epoch 8/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.5387 - accuracy: 0.7435 - val_loss: 0.6145 - val_accuracy: 0.7100
# Epoch 9/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.5289 - accuracy: 0.7505 - val_loss: 0.5596 - val_accuracy: 0.7325
# Epoch 10/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.5135 - accuracy: 0.7455 - val_loss: 0.5253 - val_accuracy: 0.7525
# Epoch 11/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.5140 - accuracy: 0.7605 - val_loss: 0.5361 - val_accuracy: 0.7650
# Epoch 12/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.4985 - accuracy: 0.7615 - val_loss: 0.5311 - val_accuracy: 0.7600
# Epoch 13/50
# 125/125 [==============================] - 10s 78ms/step - loss: 0.4843 - accuracy: 0.7765 - val_loss: 0.5583 - val_accuracy: 0.7375
# Epoch 14/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.4555 - accuracy: 0.7910 - val_loss: 0.5192 - val_accuracy: 0.7425
# Epoch 15/50
# 125/125 [==============================] - 10s 80ms/step - loss: 0.4847 - accuracy: 0.7780 - val_loss: 0.5523 - val_accuracy: 0.7425
# Epoch 16/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.4765 - accuracy: 0.7765 - val_loss: 0.5253 - val_accuracy: 0.7475
# Epoch 17/50
# 125/125 [==============================] - 10s 80ms/step - loss: 0.4496 - accuracy: 0.7965 - val_loss: 0.5853 - val_accuracy: 0.7500
# Epoch 18/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.4318 - accuracy: 0.8105 - val_loss: 0.7329 - val_accuracy: 0.7113
# Epoch 19/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.4395 - accuracy: 0.8005 - val_loss: 0.6430 - val_accuracy: 0.7613
# Epoch 20/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.4275 - accuracy: 0.8115 - val_loss: 0.5205 - val_accuracy: 0.7713
# Epoch 21/50
# 125/125 [==============================] - 10s 80ms/step - loss: 0.4269 - accuracy: 0.8245 - val_loss: 0.4985 - val_accuracy: 0.7663
# Epoch 22/50
# 125/125 [==============================] - 10s 78ms/step - loss: 0.4148 - accuracy: 0.8165 - val_loss: 0.5026 - val_accuracy: 0.7775
# Epoch 23/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.4297 - accuracy: 0.8205 - val_loss: 0.5145 - val_accuracy: 0.7462
# Epoch 24/50
# 125/125 [==============================] - 10s 78ms/step - loss: 0.4255 - accuracy: 0.8145 - val_loss: 0.5816 - val_accuracy: 0.7725
# Epoch 25/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.4218 - accuracy: 0.8105 - val_loss: 0.5715 - val_accuracy: 0.7538
# Epoch 26/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.4050 - accuracy: 0.8320 - val_loss: 0.5685 - val_accuracy: 0.7663
# Epoch 27/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.4103 - accuracy: 0.8205 - val_loss: 0.5517 - val_accuracy: 0.7563
# Epoch 28/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.4054 - accuracy: 0.8300 - val_loss: 0.5636 - val_accuracy: 0.7675
# Epoch 29/50
# 125/125 [==============================] - 10s 78ms/step - loss: 0.4017 - accuracy: 0.8235 - val_loss: 0.6917 - val_accuracy: 0.7650
# Epoch 30/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.4003 - accuracy: 0.8305 - val_loss: 0.5467 - val_accuracy: 0.7700
# Epoch 31/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.3980 - accuracy: 0.8245 - val_loss: 0.7905 - val_accuracy: 0.7400
# Epoch 32/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.3989 - accuracy: 0.8345 - val_loss: 0.5706 - val_accuracy: 0.7887
# Epoch 33/50
# 125/125 [==============================] - 10s 78ms/step - loss: 0.3801 - accuracy: 0.8350 - val_loss: 0.5450 - val_accuracy: 0.7713
# Epoch 34/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.3810 - accuracy: 0.8375 - val_loss: 0.5528 - val_accuracy: 0.7875
# Epoch 35/50
# 125/125 [==============================] - 10s 78ms/step - loss: 0.3953 - accuracy: 0.8410 - val_loss: 0.5400 - val_accuracy: 0.7613
# Epoch 36/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.3776 - accuracy: 0.8420 - val_loss: 0.6432 - val_accuracy: 0.7638
# Epoch 37/50
# 125/125 [==============================] - 10s 78ms/step - loss: 0.3838 - accuracy: 0.8400 - val_loss: 0.5022 - val_accuracy: 0.7475
# Epoch 38/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.3881 - accuracy: 0.8475 - val_loss: 0.5128 - val_accuracy: 0.7862
# Epoch 39/50
# 125/125 [==============================] - 10s 78ms/step - loss: 0.3920 - accuracy: 0.8445 - val_loss: 0.6355 - val_accuracy: 0.7625
# Epoch 40/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.3891 - accuracy: 0.8420 - val_loss: 0.5806 - val_accuracy: 0.7738
# Epoch 41/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.3890 - accuracy: 0.8500 - val_loss: 0.5226 - val_accuracy: 0.7675
# Epoch 42/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.3941 - accuracy: 0.8300 - val_loss: 0.5143 - val_accuracy: 0.7700
# Epoch 43/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.3933 - accuracy: 0.8360 - val_loss: 0.5347 - val_accuracy: 0.7713
# Epoch 44/50
# 125/125 [==============================] - 10s 78ms/step - loss: 0.3858 - accuracy: 0.8325 - val_loss: 0.4693 - val_accuracy: 0.7812
# Epoch 45/50
# 125/125 [==============================] - 10s 80ms/step - loss: 0.3797 - accuracy: 0.8410 - val_loss: 0.5464 - val_accuracy: 0.7825
# Epoch 46/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.3860 - accuracy: 0.8520 - val_loss: 0.5967 - val_accuracy: 0.7937
# Epoch 47/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.3591 - accuracy: 0.8665 - val_loss: 0.7663 - val_accuracy: 0.7650
# Epoch 48/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.3848 - accuracy: 0.8350 - val_loss: 0.8698 - val_accuracy: 0.7250
# Epoch 49/50
# 125/125 [==============================] - 10s 79ms/step - loss: 0.3910 - accuracy: 0.8475 - val_loss: 0.6019 - val_accuracy: 0.7850
# Epoch 50/50
# 125/125 [==============================] - 10s 78ms/step - loss: 0.3912 - accuracy: 0.8445 - val_loss: 0.6774 - val_accuracy: 0.7450
