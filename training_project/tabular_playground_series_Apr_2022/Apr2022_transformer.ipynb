# %%
import pandas as pd
import os
from matplotlib import pyplot as plt

# %%
current_directory = os.getcwd()
print(current_directory)
train = pd.read_csv('data/train.csv')
train_labels = pd.read_csv('data/train_labels.csv')
test = pd.read_csv('data/test.csv')
# Out:
# D:\boshi\GitHub\kears_learning\training_project\tabular_playground_series_Apr_2022

# %% [markdown]
# In this competition, you'll classify 60-second sequences of sensor data, indicating whether a subject was in either of two activity states for the duration of the sequence.
#
# ## Files and Field Descriptions
# - train.csv - the training set, comprising ~26,000 60-second recordings of thirteen biological sensors for almost one thousand experimental participants
#     - sequence - a unique id for each sequence
#     - subject - a unique id for the subject in the experiment
#     - step - time step of the recording, in one second intervals
#     - sensor_00 - sensor_12 - the value for each of the thirteen sensors at that time step
# - train_labels.csv - the class label for each sequence.
#     - sequence - the unique id for each sequence.
#     - state - the state associated to each sequence. This is the target which you are trying to predict.
# - test.csv - the test set. For each of the ~12,000 sequences, you should predict a value for that sequence's state.
# - sample_submission.csv - a sample submission file in the correct format.

# %% [markdown]
# According to the prompt, each second present one row. Every 60 rows present a `sequence`

# %% [markdown]
# Check data has missing values

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1558080 entries, 0 to 1558079
# Data columns (total 16 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   sequence   1558080 non-null  int64
#  1   subject    1558080 non-null  int64
#  2   step       1558080 non-null  int64
#  3   sensor_00  1558080 non-null  float64
#  4   sensor_01  1558080 non-null  float64
#  5   sensor_02  1558080 non-null  float64
#  6   sensor_03  1558080 non-null  float64
#  7   sensor_04  1558080 non-null  float64
#  8   sensor_05  1558080 non-null  float64
#  9   sensor_06  1558080 non-null  float64
#  10  sensor_07  1558080 non-null  float64
#  11  sensor_08  1558080 non-null  float64
#  12  sensor_09  1558080 non-null  float64
#  13  sensor_10  1558080 non-null  float64
#  14  sensor_11  1558080 non-null  float64
#  15  sensor_12  1558080 non-null  float64
# dtypes: float64(13), int64(3)
# memory usage: 190.2 MB

# %% [markdown]
# ## Feature Engineering

# %%
# add lagged feature and difference features

def add_lag_features(df):

    sensors = ['sensor_'+'%02d'%i for i in range(0, 13)]
    for sensor in sensors:
        df[sensor + '_lag1'] = df.groupby('sequence')[sensor].shift(1)
        df.fillna(0, inplace=True)
        df[sensor + '_diff1'] = df[sensor] - df[sensor + '_lag1']

    return df

# %%
groups = train['sequence']

# %%
train = add_lag_features(train)
test = add_lag_features(test)

# %%
Window = 60
y = train_labels['state'].to_numpy()
train.drop(["sequence","step","subject"], axis=1, inplace=True)
test.drop(["sequence","step","subject"], axis=1, inplace=True)

# %%
train
# Out:
#          sensor_00  sensor_01  sensor_02  sensor_03  sensor_04  sensor_05  \
# 0        -0.196291   0.112395   1.000000   0.329204  -1.004660  -0.131638
# 1        -0.447450   0.134454   1.000000  -0.658407   0.162495   0.340314
# 2         0.326893  -0.694328   1.000000   0.330088   0.473678   1.280479
# 3         0.523184   0.751050   1.000000   0.976991  -0.563287  -0.720269
# 4         0.272025   1.074580   1.000000  -0.136283   0.398579   0.044877
# ...            ...        ...        ...        ...        ...        ...
# 1558075  -0.282844  -1.217437  -1.666153   0.586726  -0.930698  -0.451010
# 1558076   0.130603   0.349790  -1.666153  -0.324779   0.775324  -0.332835
# 1558077  -0.579598   0.429622  -1.666153   0.319469   0.308861   0.282723
# 1558078   1.278980   1.711134  -1.522820   0.802655  -0.460541  -0.055348
# 1558079  -1.136012  -3.702731  -1.332820  -0.766372  -0.430027  -0.091997
#
#          sensor_06  sensor_07  sensor_08  sensor_09  ...  sensor_08_lag1  \
# 0        -0.127505   0.368702       -0.1  -0.963873  ...             0.0
# 1        -0.209472  -0.867176        0.2  -0.301301  ...            -0.1
# 2        -0.094718   0.535878        1.4   1.002168  ...             0.2
# 3         0.793260   0.951145       -0.3  -0.995665  ...             1.4
# 4         0.560109  -0.541985       -0.9   1.055636  ...            -0.3
# ...            ...        ...        ...        ...  ...             ...
# 1558075  -0.651184   0.368702        0.4   0.008671  ...            -1.2
# 1558076   0.099271   0.122137       -0.2   0.644509  ...             0.4
# 1558077  -0.512750   0.012214       -1.6  -0.424133  ...            -0.2
# 1558078   2.405282   0.043511        1.9   0.283960  ...            -1.6
# 1558079  -2.512750  -0.022901       -1.1  -0.653902  ...             1.9
#
#          sensor_08_diff1  sensor_09_lag1  sensor_09_diff1  sensor_10_lag1  \
# 0                   -0.1        0.000000        -0.963873        0.000000
# 1                    0.3       -0.963873         0.662572       -0.985069
# 2                    1.2       -0.301301         1.303468        0.082733
# 3                   -1.7        1.002168        -1.997832        0.449221
# 4                   -0.6       -0.995665         2.051301       -0.434290
# ...                  ...             ...              ...             ...
# 1558075              1.6       -0.647399         0.656069       -0.596996
# 1558076             -0.6        0.008671         0.635838       -0.723536
# 1558077             -1.4        0.644509        -1.068642        0.691407
# 1558078              3.5       -0.424133         0.708092        0.716855
# 1558079             -3.0        0.283960        -0.937861       -0.914914
#
#          sensor_10_diff1  sensor_11_lag1  sensor_11_diff1  sensor_12_lag1  \
# 0              -0.985069        0.000000         0.531893        0.000000
# 1               1.067802        0.531893        -0.763374        4.751492
# 2               0.366488       -0.231481        -0.354938        0.454390
# 3              -0.883512       -0.586420         1.931070       -4.736147
# 4               1.246921        1.344650        -1.221193        0.429241
# ...                  ...             ...              ...             ...
# 1558075        -0.126540       -0.728395         0.374486        0.639812
# 1558076         1.414943       -0.353909        -0.259259       -0.914749
# 1558077         0.025447       -0.613169         2.241770       -0.515772
# 1558078        -1.631769        1.628601        -1.264403        0.928389
# 1558079         0.496398        0.364198        -1.817901        0.211424
#
#          sensor_12_diff1
# 0               4.751492
# 1              -4.297101
# 2              -5.190537
# 3               5.165388
# 4              -0.652600
# ...                  ...
# 1558075        -1.554561
# 1558076         0.398977
# 1558077         1.444160
# 1558078        -0.716965
# 1558079        -1.772805
#
# [1558080 rows x 39 columns]

# %%
y.shape
# Out:
# (25968,)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
sc.fit(train)
X_train = sc.transform(train)
X_test = sc.transform(test)

# %% [markdown]
# ## Reshape Data

# %%
y_train = y.copy()
X_train = X_train.reshape(-1, Window, X_train.shape[-1])
X_test = X_test.reshape(-1, Window, X_test.shape[-1])

# %%
print(y_train.shape, X_train.shape, X_test.shape)
# Out:
# (25968,) (25968, 60, 39) (12218, 60, 39)

# %% [markdown]
# ## Build Bidirectional Model

# %%
from keras import Model, layers
from keras.layers import *
from keras.callbacks import *
from keras.metrics import AUC

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0.0):
    # Attention and Normalization
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="selu")(res)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

# %%
def build_model(
    shape,
    head_size = 64,
    num_heads = 4,
    ff_dim=32,
    num_transformer_blocks=4,
    mlp_units=[128],
    dropout=0.0,
    mlp_dropout=0.4,
):
    inputs = Input(shape=shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D()(x)
    for dim in mlp_units:
        x = Dense(dim, activation="selu")(x)
        x = Dropout(mlp_dropout)(x)

    outputs = Dense(1, activation='sigmoid')(x)

    model = Model(inputs=inputs, outputs=outputs, name='lstm_model')

    model.compile(optimizer='adam',
                      loss='binary_crossentropy',
                      metrics=[AUC(name = 'auc')])
    return  model

# %%
model = build_model(shape=X_train.shape[1:])
model.summary()
# Out:
# Model: "lstm_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_15 (InputLayer)          [(None, 60, 39)]     0           []
#
#  multi_head_attention_44 (Multi  (None, 60, 39)      81447       ['input_15[0][0]',
#  HeadAttention)                                                   'input_15[0][0]']
#
#  dropout_102 (Dropout)          (None, 60, 39)       0           ['multi_head_attention_44[0][0]']
#
#  layer_normalization_88 (LayerN  (None, 60, 39)      78          ['dropout_102[0][0]']
#  ormalization)
#
#  tf.__operators__.add_88 (TFOpL  (None, 60, 39)      0           ['layer_normalization_88[0][0]',
#  ambda)                                                           'input_15[0][0]']
#
#  conv1d_88 (Conv1D)             (None, 60, 32)       1280        ['tf.__operators__.add_88[0][0]']
#
#  dropout_103 (Dropout)          (None, 60, 32)       0           ['conv1d_88[0][0]']
#
#  conv1d_89 (Conv1D)             (None, 60, 39)       1287        ['dropout_103[0][0]']
#
#  layer_normalization_89 (LayerN  (None, 60, 39)      78          ['conv1d_89[0][0]']
#  ormalization)
#
#  tf.__operators__.add_89 (TFOpL  (None, 60, 39)      0           ['layer_normalization_89[0][0]',
#  ambda)                                                           'tf.__operators__.add_88[0][0]']
#
#  multi_head_attention_45 (Multi  (None, 60, 39)      81447       ['tf.__operators__.add_89[0][0]',
#  HeadAttention)                                                   'tf.__operators__.add_89[0][0]']
#
#  dropout_104 (Dropout)          (None, 60, 39)       0           ['multi_head_attention_45[0][0]']
#
#  layer_normalization_90 (LayerN  (None, 60, 39)      78          ['dropout_104[0][0]']
#  ormalization)
#
#  tf.__operators__.add_90 (TFOpL  (None, 60, 39)      0           ['layer_normalization_90[0][0]',
#  ambda)                                                           'tf.__operators__.add_89[0][0]']
#
#  conv1d_90 (Conv1D)             (None, 60, 32)       1280        ['tf.__operators__.add_90[0][0]']
#
#  dropout_105 (Dropout)          (None, 60, 32)       0           ['conv1d_90[0][0]']
#
#  conv1d_91 (Conv1D)             (None, 60, 39)       1287        ['dropout_105[0][0]']
#
#  layer_normalization_91 (LayerN  (None, 60, 39)      78          ['conv1d_91[0][0]']
#  ormalization)
#
#  tf.__operators__.add_91 (TFOpL  (None, 60, 39)      0           ['layer_normalization_91[0][0]',
#  ambda)                                                           'tf.__operators__.add_90[0][0]']
#
#  multi_head_attention_46 (Multi  (None, 60, 39)      81447       ['tf.__operators__.add_91[0][0]',
#  HeadAttention)                                                   'tf.__operators__.add_91[0][0]']
#
#  dropout_106 (Dropout)          (None, 60, 39)       0           ['multi_head_attention_46[0][0]']
#
#  layer_normalization_92 (LayerN  (None, 60, 39)      78          ['dropout_106[0][0]']
#  ormalization)
#
#  tf.__operators__.add_92 (TFOpL  (None, 60, 39)      0           ['layer_normalization_92[0][0]',
#  ambda)                                                           'tf.__operators__.add_91[0][0]']
#
#  conv1d_92 (Conv1D)             (None, 60, 32)       1280        ['tf.__operators__.add_92[0][0]']
#
#  dropout_107 (Dropout)          (None, 60, 32)       0           ['conv1d_92[0][0]']
#
#  conv1d_93 (Conv1D)             (None, 60, 39)       1287        ['dropout_107[0][0]']
#
#  layer_normalization_93 (LayerN  (None, 60, 39)      78          ['conv1d_93[0][0]']
#  ormalization)
#
#  tf.__operators__.add_93 (TFOpL  (None, 60, 39)      0           ['layer_normalization_93[0][0]',
#  ambda)                                                           'tf.__operators__.add_92[0][0]']
#
#  multi_head_attention_47 (Multi  (None, 60, 39)      81447       ['tf.__operators__.add_93[0][0]',
#  HeadAttention)                                                   'tf.__operators__.add_93[0][0]']
#
#  dropout_108 (Dropout)          (None, 60, 39)       0           ['multi_head_attention_47[0][0]']
#
#  layer_normalization_94 (LayerN  (None, 60, 39)      78          ['dropout_108[0][0]']
#  ormalization)
#
#  tf.__operators__.add_94 (TFOpL  (None, 60, 39)      0           ['layer_normalization_94[0][0]',
#  ambda)                                                           'tf.__operators__.add_93[0][0]']
#
#  conv1d_94 (Conv1D)             (None, 60, 32)       1280        ['tf.__operators__.add_94[0][0]']
#
#  dropout_109 (Dropout)          (None, 60, 32)       0           ['conv1d_94[0][0]']
#
#  conv1d_95 (Conv1D)             (None, 60, 39)       1287        ['dropout_109[0][0]']
#
#  layer_normalization_95 (LayerN  (None, 60, 39)      78          ['conv1d_95[0][0]']
#  ormalization)
#
#  tf.__operators__.add_95 (TFOpL  (None, 60, 39)      0           ['layer_normalization_95[0][0]',
#  ambda)                                                           'tf.__operators__.add_94[0][0]']
#
#  global_average_pooling1d_14 (G  (None, 60)          0           ['tf.__operators__.add_95[0][0]']
#  lobalAveragePooling1D)
#
#  dense_28 (Dense)               (None, 128)          7808        ['global_average_pooling1d_14[0][
#                                                                  0]']
#
#  dropout_110 (Dropout)          (None, 128)          0           ['dense_28[0][0]']
#
#  dense_29 (Dense)               (None, 1)            129         ['dropout_110[0][0]']
#
# ==================================================================================================
# Total params: 344,617
# Trainable params: 344,617
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Reson for why add Fallten in last dense
#
# An LSTM layer consists of different LSTM cells that are processed sequentially. As seen in the figure below, the first cell takes an input/embedding calculates a hidden state and the next cell uses its input and the hidden state at previous time step to compute its own hidden state. Basically the arrows between the cells also pass the hidden states. <b>If you do return_sequences=False, the lstm layer only outputs the very last hidden state! (h_4 in the figure). So, all those information from all inputs and cells are embedded in a single fixed size information and it can not contain lots of information.</b> This is why, your accuracy is not good when you only use the last hidden state.
#
# When you do `return_sequences=True`, lstm layer outputs every hidden state, so the next layers have access to all hidden states and they contain naturally more information. However, the LSTM layer returns a matrix. You can also see this in your model summary. It returns a matrix of size (None, 500, 128). None is basically number of samples in your batch, you can forget about it. 500 is your input size, and 128 is your hidden state size. <b>The dense layer can not process a matrix, it has to be a vector. That why you need to apply flatten and what it does is basically just to open up the 2D matrix and represent it as 1D vector.</b> Therefore, the size of your Flatten layer is 64000 because 500*128 = 64000. And Of course with more hidden states, the accuracy is better as they contain more information.

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, show_shapes=True)

# %%
def plot_hist(hist, metric='auc', ax=None, fold=0):
    if ax==None:
        plt.plot(hist.history[metric])
        plt.plot(hist.history["val_" + metric])
        plt.title(f"model performance fold {fold}")
        plt.ylabel("area_under_curve")
        plt.xlabel("epoch")
        plt.legend(["train", "validation"], loc="upper left")
        plt.show()
        return
    else:
        ax.plot(hist.history[metric])
        ax.plot(hist.history["val_" + metric])
        ax.set_title(f"model performance fold {fold}")
        ax.set_ylabel("area_under_curve")
        ax.set_xlabel("epoch")
        ax.legend(["train", "validation"], loc="upper left")

# %%
from sklearn.model_selection import GroupKFold
from sklearn.metrics import roc_auc_score
import gc


def fit_model(nfold, epochs=60, batch_size=32, verbose=False):
    test_preds = []
    auc = []
    ncols = 5 if nfold > 5 else nfold
    nrows = int(round(nfold / ncols))

    col, row = 0, 0
    fig, axes = plt.subplots(nrows, ncols, figsize=(20, round(nrows*20/ncols)))

    kf = GroupKFold(n_splits=nfold)

    for fold, (train_idx, test_idx) in enumerate(kf.split(X_train, y_train, groups.unique())):
        print(f"Fold: {fold+1}", end=' ')
        X_train_part, X_valid = X_train[train_idx], X_train[test_idx]
        y_train_part, y_valid = y_train[train_idx], y_train[test_idx]


        lr = ReduceLROnPlateau(monitor="val_auc", mode='max', factor=0.7, patience=4, verbose=False)
        es = EarlyStopping(monitor='val_auc',mode='max', patience=10, verbose=False,restore_best_weights=True)
        model = build_model(shape=X_train.shape[1:])
        history = model.fit(X_train_part, y_train_part, validation_data=(X_valid, y_valid), epochs=epochs, batch_size=batch_size,
                            callbacks=[es,lr], verbose=verbose)

        y_pred = model.predict(X_valid).squeeze()
        auc_score = roc_auc_score(y_valid, y_pred)
        print(f'auc: {round(auc_score, 5)}')
        test_preds.append(model.predict(X_test).squeeze())
        auc.append(auc_score)

        plot_hist(history, metric='auc', ax=axes[col] if nrows <= 1 else axes[row][col], fold=fold+1)
        del X_train_part, X_valid, y_train_part, y_valid, history, model
        gc.collect()

        col += 1
        if col >= ncols:
            row += 1
            col = 0
    return test_preds, auc

folds = 4
(test_preds, auc) = fit_model(folds, epochs=60, batch_size=64, verbose=True)
# Out:
# Fold: 1 Epoch 1/60
# 305/305 [==============================] - 12s 30ms/step - loss: 0.6906 - auc: 0.6176 - val_loss: 0.6231 - val_auc: 0.7167 - lr: 0.0010
# Epoch 2/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.6196 - auc: 0.7191 - val_loss: 0.5882 - val_auc: 0.7619 - lr: 0.0010
# Epoch 3/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.5673 - auc: 0.7810 - val_loss: 0.5802 - val_auc: 0.8066 - lr: 0.0010
# Epoch 4/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.5181 - auc: 0.8234 - val_loss: 0.5036 - val_auc: 0.8338 - lr: 0.0010
# Epoch 5/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.4924 - auc: 0.8425 - val_loss: 0.4978 - val_auc: 0.8392 - lr: 0.0010
# Epoch 6/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.4727 - auc: 0.8550 - val_loss: 0.4843 - val_auc: 0.8466 - lr: 0.0010
# Epoch 7/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.4521 - auc: 0.8687 - val_loss: 0.4907 - val_auc: 0.8520 - lr: 0.0010
# Epoch 8/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.4430 - auc: 0.8740 - val_loss: 0.4745 - val_auc: 0.8534 - lr: 0.0010
# Epoch 9/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.4333 - auc: 0.8798 - val_loss: 0.4826 - val_auc: 0.8511 - lr: 0.0010
# Epoch 10/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.4241 - auc: 0.8843 - val_loss: 0.4800 - val_auc: 0.8521 - lr: 0.0010
# Epoch 11/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.4144 - auc: 0.8905 - val_loss: 0.4803 - val_auc: 0.8532 - lr: 0.0010
# Epoch 12/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.4111 - auc: 0.8924 - val_loss: 0.5004 - val_auc: 0.8544 - lr: 0.0010
# Epoch 13/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3994 - auc: 0.8986 - val_loss: 0.4856 - val_auc: 0.8567 - lr: 0.0010
# Epoch 14/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3896 - auc: 0.9033 - val_loss: 0.4969 - val_auc: 0.8568 - lr: 0.0010
# Epoch 15/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.3841 - auc: 0.9064 - val_loss: 0.4757 - val_auc: 0.8620 - lr: 0.0010
# Epoch 16/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.3808 - auc: 0.9084 - val_loss: 0.4859 - val_auc: 0.8623 - lr: 0.0010
# Epoch 17/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3666 - auc: 0.9155 - val_loss: 0.4974 - val_auc: 0.8593 - lr: 0.0010
# Epoch 18/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3685 - auc: 0.9145 - val_loss: 0.4778 - val_auc: 0.8606 - lr: 0.0010
# Epoch 19/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3533 - auc: 0.9213 - val_loss: 0.5016 - val_auc: 0.8582 - lr: 0.0010
# Epoch 20/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3481 - auc: 0.9241 - val_loss: 0.4756 - val_auc: 0.8599 - lr: 0.0010
# Epoch 21/60
# 305/305 [==============================] - 8s 28ms/step - loss: 0.3180 - auc: 0.9368 - val_loss: 0.4848 - val_auc: 0.8641 - lr: 7.0000e-04
# Epoch 22/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3060 - auc: 0.9416 - val_loss: 0.5358 - val_auc: 0.8580 - lr: 7.0000e-04
# Epoch 23/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.2961 - auc: 0.9452 - val_loss: 0.5287 - val_auc: 0.8630 - lr: 7.0000e-04
# Epoch 24/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.2905 - auc: 0.9469 - val_loss: 0.5223 - val_auc: 0.8587 - lr: 7.0000e-04
# Epoch 25/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.2853 - auc: 0.9489 - val_loss: 0.5200 - val_auc: 0.8571 - lr: 7.0000e-04
# Epoch 26/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.2527 - auc: 0.9598 - val_loss: 0.5737 - val_auc: 0.8554 - lr: 4.9000e-04
# Epoch 27/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.2366 - auc: 0.9651 - val_loss: 0.5776 - val_auc: 0.8550 - lr: 4.9000e-04
# Epoch 28/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.2230 - auc: 0.9685 - val_loss: 0.6305 - val_auc: 0.8537 - lr: 4.9000e-04
# Epoch 29/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.2196 - auc: 0.9699 - val_loss: 0.6268 - val_auc: 0.8562 - lr: 4.9000e-04
# Epoch 30/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.1897 - auc: 0.9771 - val_loss: 0.6819 - val_auc: 0.8469 - lr: 3.4300e-04
# Epoch 31/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.1800 - auc: 0.9796 - val_loss: 0.7209 - val_auc: 0.8455 - lr: 3.4300e-04
# auc: 0.86414
# Fold: 2 Epoch 1/60
# 305/305 [==============================] - 11s 30ms/step - loss: 0.6859 - auc: 0.6172 - val_loss: 0.6477 - val_auc: 0.6871 - lr: 0.0010
# Epoch 2/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.6202 - auc: 0.7184 - val_loss: 0.5960 - val_auc: 0.7487 - lr: 0.0010
# Epoch 3/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.5769 - auc: 0.7680 - val_loss: 0.5344 - val_auc: 0.8107 - lr: 0.0010
# Epoch 4/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.5289 - auc: 0.8141 - val_loss: 0.5126 - val_auc: 0.8231 - lr: 0.0010
# Epoch 5/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.5023 - auc: 0.8332 - val_loss: 0.4956 - val_auc: 0.8408 - lr: 0.0010
# Epoch 6/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.4878 - auc: 0.8442 - val_loss: 0.4972 - val_auc: 0.8370 - lr: 0.0010
# Epoch 7/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.4729 - auc: 0.8553 - val_loss: 0.4912 - val_auc: 0.8405 - lr: 0.0010
# Epoch 8/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.4578 - auc: 0.8650 - val_loss: 0.4892 - val_auc: 0.8463 - lr: 0.0010
# Epoch 9/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.4456 - auc: 0.8724 - val_loss: 0.4875 - val_auc: 0.8435 - lr: 0.0010
# Epoch 10/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.4392 - auc: 0.8763 - val_loss: 0.4778 - val_auc: 0.8550 - lr: 0.0010
# Epoch 11/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.4283 - auc: 0.8830 - val_loss: 0.4880 - val_auc: 0.8462 - lr: 0.0010
# Epoch 12/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.4188 - auc: 0.8878 - val_loss: 0.4706 - val_auc: 0.8545 - lr: 0.0010
# Epoch 13/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.4096 - auc: 0.8934 - val_loss: 0.4816 - val_auc: 0.8584 - lr: 0.0010
# Epoch 14/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3944 - auc: 0.9010 - val_loss: 0.4927 - val_auc: 0.8546 - lr: 0.0010
# Epoch 15/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3877 - auc: 0.9048 - val_loss: 0.4663 - val_auc: 0.8613 - lr: 0.0010
# Epoch 16/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3777 - auc: 0.9099 - val_loss: 0.4860 - val_auc: 0.8624 - lr: 0.0010
# Epoch 17/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3704 - auc: 0.9136 - val_loss: 0.4632 - val_auc: 0.8638 - lr: 0.0010
# Epoch 18/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3616 - auc: 0.9179 - val_loss: 0.4618 - val_auc: 0.8631 - lr: 0.0010
# Epoch 19/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3586 - auc: 0.9194 - val_loss: 0.4776 - val_auc: 0.8607 - lr: 0.0010
# Epoch 20/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3457 - auc: 0.9252 - val_loss: 0.5022 - val_auc: 0.8601 - lr: 0.0010
# Epoch 21/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3388 - auc: 0.9282 - val_loss: 0.4838 - val_auc: 0.8653 - lr: 0.0010
# Epoch 22/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3367 - auc: 0.9293 - val_loss: 0.5010 - val_auc: 0.8656 - lr: 0.0010
# Epoch 23/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.3266 - auc: 0.9336 - val_loss: 0.5293 - val_auc: 0.8592 - lr: 0.0010
# Epoch 24/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.3220 - auc: 0.9358 - val_loss: 0.4849 - val_auc: 0.8663 - lr: 0.0010
# Epoch 25/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3063 - auc: 0.9420 - val_loss: 0.5199 - val_auc: 0.8618 - lr: 0.0010
# Epoch 26/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.2995 - auc: 0.9447 - val_loss: 0.5235 - val_auc: 0.8608 - lr: 0.0010
# Epoch 27/60
# 305/305 [==============================] - 8s 28ms/step - loss: 0.2989 - auc: 0.9448 - val_loss: 0.5271 - val_auc: 0.8594 - lr: 0.0010
# Epoch 28/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.2846 - auc: 0.9502 - val_loss: 0.5481 - val_auc: 0.8576 - lr: 0.0010
# Epoch 29/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.2535 - auc: 0.9606 - val_loss: 0.5555 - val_auc: 0.8629 - lr: 7.0000e-04
# Epoch 30/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.2400 - auc: 0.9647 - val_loss: 0.5909 - val_auc: 0.8538 - lr: 7.0000e-04
# Epoch 31/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.2296 - auc: 0.9678 - val_loss: 0.6229 - val_auc: 0.8560 - lr: 7.0000e-04
# Epoch 32/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.2297 - auc: 0.9677 - val_loss: 0.6241 - val_auc: 0.8555 - lr: 7.0000e-04
# Epoch 33/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.1895 - auc: 0.9780 - val_loss: 0.6973 - val_auc: 0.8538 - lr: 4.9000e-04
# Epoch 34/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.1822 - auc: 0.9797 - val_loss: 0.7236 - val_auc: 0.8501 - lr: 4.9000e-04
# auc: 0.86638
# Fold: 3 Epoch 1/60
# 305/305 [==============================] - 11s 30ms/step - loss: 0.6807 - auc: 0.6312 - val_loss: 0.6151 - val_auc: 0.7325 - lr: 0.0010
# Epoch 2/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.6261 - auc: 0.7079 - val_loss: 0.6160 - val_auc: 0.7283 - lr: 0.0010
# Epoch 3/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.5818 - auc: 0.7651 - val_loss: 0.5482 - val_auc: 0.7957 - lr: 0.0010
# Epoch 4/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.5272 - auc: 0.8151 - val_loss: 0.5401 - val_auc: 0.8221 - lr: 0.0010
# Epoch 5/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.4905 - auc: 0.8420 - val_loss: 0.4944 - val_auc: 0.8402 - lr: 0.0010
# Epoch 6/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.4707 - auc: 0.8561 - val_loss: 0.4969 - val_auc: 0.8498 - lr: 0.0010
# Epoch 7/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.4613 - auc: 0.8626 - val_loss: 0.4814 - val_auc: 0.8524 - lr: 0.0010
# Epoch 8/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.4387 - auc: 0.8767 - val_loss: 0.4812 - val_auc: 0.8552 - lr: 0.0010
# Epoch 9/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.4298 - auc: 0.8815 - val_loss: 0.4684 - val_auc: 0.8583 - lr: 0.0010
# Epoch 10/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.4190 - auc: 0.8882 - val_loss: 0.4764 - val_auc: 0.8565 - lr: 0.0010
# Epoch 11/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.4068 - auc: 0.8943 - val_loss: 0.4772 - val_auc: 0.8593 - lr: 0.0010
# Epoch 12/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3958 - auc: 0.9001 - val_loss: 0.4611 - val_auc: 0.8641 - lr: 0.0010
# Epoch 13/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3927 - auc: 0.9020 - val_loss: 0.4584 - val_auc: 0.8634 - lr: 0.0010
# Epoch 14/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3874 - auc: 0.9048 - val_loss: 0.4737 - val_auc: 0.8655 - lr: 0.0010
# Epoch 15/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3756 - auc: 0.9104 - val_loss: 0.5122 - val_auc: 0.8642 - lr: 0.0010
# Epoch 16/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3662 - auc: 0.9159 - val_loss: 0.4708 - val_auc: 0.8645 - lr: 0.0010
# Epoch 17/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3580 - auc: 0.9188 - val_loss: 0.4795 - val_auc: 0.8648 - lr: 0.0010
# Epoch 18/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3512 - auc: 0.9224 - val_loss: 0.4743 - val_auc: 0.8663 - lr: 0.0010
# Epoch 19/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3439 - auc: 0.9256 - val_loss: 0.4918 - val_auc: 0.8644 - lr: 0.0010
# Epoch 20/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3409 - auc: 0.9274 - val_loss: 0.4852 - val_auc: 0.8681 - lr: 0.0010
# Epoch 21/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3330 - auc: 0.9304 - val_loss: 0.4796 - val_auc: 0.8618 - lr: 0.0010
# Epoch 22/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3298 - auc: 0.9317 - val_loss: 0.4919 - val_auc: 0.8655 - lr: 0.0010
# Epoch 23/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.3181 - auc: 0.9366 - val_loss: 0.5066 - val_auc: 0.8636 - lr: 0.0010
# Epoch 24/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.3087 - auc: 0.9404 - val_loss: 0.5183 - val_auc: 0.8663 - lr: 0.0010
# Epoch 25/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.2834 - auc: 0.9498 - val_loss: 0.5486 - val_auc: 0.8569 - lr: 7.0000e-04
# Epoch 26/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.2716 - auc: 0.9538 - val_loss: 0.5820 - val_auc: 0.8641 - lr: 7.0000e-04
# Epoch 27/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.2592 - auc: 0.9583 - val_loss: 0.5269 - val_auc: 0.8592 - lr: 7.0000e-04
# Epoch 28/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.2493 - auc: 0.9613 - val_loss: 0.5465 - val_auc: 0.8630 - lr: 7.0000e-04
# Epoch 29/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.2179 - auc: 0.9701 - val_loss: 0.6196 - val_auc: 0.8620 - lr: 4.9000e-04
# Epoch 30/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.2023 - auc: 0.9744 - val_loss: 0.6816 - val_auc: 0.8480 - lr: 4.9000e-04
# auc: 0.86825
# Fold: 4 Epoch 1/60
# 305/305 [==============================] - 11s 30ms/step - loss: 0.6897 - auc: 0.6248 - val_loss: 0.6323 - val_auc: 0.7064 - lr: 0.0010
# Epoch 2/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.6257 - auc: 0.7090 - val_loss: 0.5859 - val_auc: 0.7641 - lr: 0.0010
# Epoch 3/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.5863 - auc: 0.7596 - val_loss: 0.5611 - val_auc: 0.8030 - lr: 0.0010
# Epoch 4/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.5436 - auc: 0.8007 - val_loss: 0.5095 - val_auc: 0.8367 - lr: 0.0010
# Epoch 5/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.5116 - auc: 0.8268 - val_loss: 0.4746 - val_auc: 0.8529 - lr: 0.0010
# Epoch 6/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.4838 - auc: 0.8471 - val_loss: 0.4935 - val_auc: 0.8445 - lr: 0.0010
# Epoch 7/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.4739 - auc: 0.8534 - val_loss: 0.4930 - val_auc: 0.8538 - lr: 0.0010
# Epoch 8/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.4634 - auc: 0.8615 - val_loss: 0.4689 - val_auc: 0.8578 - lr: 0.0010
# Epoch 9/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.4478 - auc: 0.8704 - val_loss: 0.4628 - val_auc: 0.8640 - lr: 0.0010
# Epoch 10/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.4352 - auc: 0.8775 - val_loss: 0.4700 - val_auc: 0.8678 - lr: 0.0010
# Epoch 11/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.4192 - auc: 0.8870 - val_loss: 0.4694 - val_auc: 0.8610 - lr: 0.0010
# Epoch 12/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.4147 - auc: 0.8896 - val_loss: 0.4686 - val_auc: 0.8683 - lr: 0.0010
# Epoch 13/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.4018 - auc: 0.8970 - val_loss: 0.4405 - val_auc: 0.8755 - lr: 0.0010
# Epoch 14/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.3950 - auc: 0.9006 - val_loss: 0.4503 - val_auc: 0.8730 - lr: 0.0010
# Epoch 15/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.3863 - auc: 0.9049 - val_loss: 0.4526 - val_auc: 0.8692 - lr: 0.0010
# Epoch 16/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.3743 - auc: 0.9108 - val_loss: 0.4452 - val_auc: 0.8728 - lr: 0.0010
# Epoch 17/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.3652 - auc: 0.9151 - val_loss: 0.4486 - val_auc: 0.8738 - lr: 0.0010
# Epoch 18/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.3308 - auc: 0.9311 - val_loss: 0.4813 - val_auc: 0.8740 - lr: 7.0000e-04
# Epoch 19/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.3179 - auc: 0.9366 - val_loss: 0.4864 - val_auc: 0.8722 - lr: 7.0000e-04
# Epoch 20/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.3083 - auc: 0.9402 - val_loss: 0.4945 - val_auc: 0.8704 - lr: 7.0000e-04
# Epoch 21/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.2946 - auc: 0.9457 - val_loss: 0.5199 - val_auc: 0.8697 - lr: 7.0000e-04
# Epoch 22/60
# 305/305 [==============================] - 9s 29ms/step - loss: 0.2689 - auc: 0.9549 - val_loss: 0.5583 - val_auc: 0.8727 - lr: 4.9000e-04
# Epoch 23/60
# 305/305 [==============================] - 9s 28ms/step - loss: 0.2493 - auc: 0.9613 - val_loss: 0.5835 - val_auc: 0.8663 - lr: 4.9000e-04
# auc: 0.87555

# %% [markdown]
# ## Submit Data

# %%
print(f"the mean AUC for the {folds} folds is : {round(np.mean(auc)*100,3)}")
# Out:
# the mean AUC for the 4 folds is : 86.823

# %%
auc
# Out:
# [0.860568077407891, 0.8577435207972534, 0.874267229596331, 0.880342370342078]

# %%
sub_data = pd.read_csv("data/sample_submission.csv")

# %%
np.array(auc).argmax()
# Out:
# 3

# %%
sub_data['state'] = sum(test_preds)/folds

# %%
sub_data.state = (sub_data.state > 0.5).astype(int)

# %%
sub_data
# Out:
#        sequence  state
# 0         25968      1
# 1         25969      1
# 2         25970      0
# 3         25971      1
# 4         25972      0
# ...         ...    ...
# 12213     38181      0
# 12214     38182      1
# 12215     38183      1
# 12216     38184      0
# 12217     38185      0
#
# [12218 rows x 2 columns]

# %%
sub_data.to_csv('submission.csv', index=False)
