# %%
import keras
keras.__version__
# Out:
# '2.8.0'

# %% [markdown]
# # Text generation with LSTM
#
# This notebook contains the code samples found in Chapter 8, Section 1 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ----
#
# [...]
#
# ## Implementing character-level LSTM text generation
#
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a
# language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this
# example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model
# we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the
# English language.

# %% [markdown]
# ## Preparing the data
#
# Let's start by downloading the corpus and converting it to lowercase:

# %%
from keras.utils.data_utils import get_file
import numpy as np

path = get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 4s 6us/step
# 614400/600901 [==============================] - 4s 6us/step
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30304/3589888839.py in <module>
#       5     'nietzsche.txt',
#       6     origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
# ----> 7 text = open(path).read().lower()
#       8 print('Corpus length:', len(text))
#
# UnicodeDecodeError: 'cp950' codec can't decode byte 0xc3 in position 567874: illegal multibyte sequence

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of
# shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot
# encoded characters that come right after each extracted sequence.

# %%
text = open(path, encoding="utf-8").read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 600893

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...
# C:\Users\boshi\AppData\Local\Temp/ipykernel_30304/4107833881.py:26: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
# C:\Users\boshi\AppData\Local\Temp/ipykernel_30304/4107833881.py:27: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %% [markdown]
# ## Building the network
#
# Our network is a single `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. But let us note that
# recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in
# recent times.

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:

# %%
from keras.optimizers import rmsprop_v2
optimizer = rmsprop_v2.RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the language model and sampling from it
#
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model,
# and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures
# after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of
# temperature in the sampling strategy.

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# 1565/1565 [==============================] - 12s 6ms/step - loss: 2.0188
# --- Generating with seed: "; only in their simulations, or in their weaker moments, in
# "
# ------ temperature: 0.2
# ; only in their simulations, or in their weaker moments, in
# the seem to be means of the seess of the seess it is means and self--and in the stand is the sound of the serves that the seed of the most of the seess and serves of the seart of the sense of the sense of the contriestion of the seens of the sees is in the come in the sees to the seess of the sense of the come any the greates of the sees the sees of the sees of the sees is the serves to the seess
# ------ temperature: 0.5
# the sees of the sees of the sees is the serves to the seess of the viction--christon the reself this which see something the hormaness of contried of this lived of the grance of the metticism and the sees of the means it man the highely the seriet of men to in the which sometheng is the rese and of the come has decent, though the can of the presence of the such is not of the hifteren to be the servest and are
# in men mastes, in the make the comorse of the b
# ------ temperature: 1.0
# vest and are
# in men mastes, in the make the comorse of the be sceasic xtepureand nendly the philosopherth, "oo mithe wulch, this
# prescience,
# if the own quemty with seeds in most the came serfoble consequence, eyo lo. hispor as anys
# that
# whith, what the "endire
#
# ay
# asficte-"indertates of, hout becalited in thein od confuc that wich ofe prangereanis any wanded comeralizedivicty; at net
# into compreasple  ow2s borquivesd, putable in its from the gave. if the
# ------ temperature: 1.2
# sple  ow2s borquivesd, putable in its from the gave. if the cours
# shorsubs, with irseavediblek.
#
#
# by what woosintre, chrinstulies orde onerest other
# armakicast dard rivery nen a meor ciwarity: means fisirrienglendences of asgutethoo.
# e-morear meroz, thle eed or
# tive at acrtienss mentedable
# so-do. indivisamenctios life entire form hraf
# ers an ethated spirit of a reapation of sas.
#
#
#
#
#
#
# of the dispobre of grany is masal hyman faicise, fore, it appe,ietificak
# epoch 2
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.6190
# --- Generating with seed: "n body and soul. an educator
# who nowadays preached truthfuln"
# ------ temperature: 0.2
# n body and soul. an educator
# who nowadays preached truthfulness and the present a man of the present and something the deception of the present man and a morality of the spirit and the same the morality of the power and the sensuation of the such a man of the present and all the present and in the present and something the power and perhaps to stander of the present to the interest in the all the present and the more something the present and the condition
# ------ temperature: 0.5
# present and the more something the present and the condition of their not and thinks and always for the all the sensed
# and on the last all the superars present man it is all and the good servante
# philosophers of the think it as the preparable, their a subjuction of it is something the generated superar and all the same the philosophers and one and classing of the sensuation, and ourselves of a not all a distorting that it be a man importain for all the con
# ------ temperature: 1.0
#  all a distorting that it be a man importain for all the constancess: the low not ethers becoiders retadenoments--for atteass who for it kind, by . they at a chelists and pentures a the man but upon a man lofy skepwions
# opposity degiced whhich who antrous a huncepariul, on headive and the hulad it is
# only whether painurest amaquates of the acts of the spirst, even the attish for
# this debrethimant
# diswimide he wishomising in
# the faored divin" is cases of it
# ------ temperature: 1.2
# diswimide he wishomising in
# the faored divin" is cases of itedisiomance loves and manity, states as floogiblisal philoposily!
# in1erpcoup follo men -fouss as, is own power alfisy through now mude
# mormod
# penduseptiondf,mencled so naculime,st and
# a
# l. by gailsablistic three, learsain thronging,
# diwstra1blty: tho phain your, tergaable nots. it is itsially upolguands gawerty, and caintementakes expemsiouly to how
# needve-if menserables tod to tensieate owise, th
# epoch 3
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.5270
# --- Generating with seed: "ing significance of words! the people on their part may
# thin"
# ------ temperature: 0.2
# ing significance of words! the people on their part may
# think of the sensition of the experience of the self of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sensition of the sense of the sense of the art of the destruction of the sense of the sense of the species of the most something of the sense of the sense of the own the sense of the sense of the sensition of the sense of the despect, and and an artiste
# ------ temperature: 0.5
# he sensition of the sense of the despect, and and an artistence of the world--the sense of him, as one of the sense of the accordant, the philosophers, and more weaker the developments consideration of the the first as any in the all and the weak himself be the warn only one must him as he more says--that the high, attained, and self of
# the knows it is no carable for the sense and soul, which a such as its learned a not our worth which has once who have al
# ------ temperature: 1.0
# ch as its learned a not our worth which has once who have all vigod ? new usulw the honting she claince to be developmentsh""--in bekenose tosthen and dialorlow, as a my comingfulfuly, about sin
# to all botken, him, in the hlad concusion".
#
#
# 27
#
# =the
# will
# virtues of antifiet time truth is
# notifien), it hex a my pain than unhar "scatichificants. the
# "  couling
# crualte, as
# seeking disciviving, thing absoluted!--that
# no methous
# "natyly--at him, hing. they case
# ------ temperature: 1.2
# absoluted!--that
# no methous
# "natyly--at him, hing. they casenito only this first will metrescic, wuldquifie im tempor deceptions imposiond stanes
# god imuly-as lone)s.
#
# p, has
# not b-stunable-inamen who wass unfusite rigarlal
# aristretanrate through
# which
# fros it, however arrow our whoy one much
# frem:--oseaninghys of the huads
# essenine and
# verctive than (cases where as nastlf wend, un instencious
# iep," would could arton of
# the
# lous poasonable necessary; hen-e
# epoch 4
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.4799
# --- Generating with seed: "ly personal manner: some will not give up their
# "responsibil"
# ------ temperature: 0.2
# ly personal manner: some will not give up their
# "responsibility of the sense of the entice of the sense of the false of the soul as the sense of the senses and and it is the stringutation of the sense of the conduct the sense of the sense of the senses and the contising the conduct the sout the more in the sense of the some man which the sense of the sense of the sense of the condition of the the some the sense of such the sense of the sense of the sense o
# ------ temperature: 0.5
# some the sense of such the sense of the sense of the sense of the present the valuations and so mankind which is a may by self-values and have value of the good and
# the in the recognised and the noble the case himself, the woman they have been that the far as a sopes of moral themow of an and the bad them in the capeble them, and the tome the something is the sentiment and part of the distingule of the false--to the sort of the false of the own allow are t
# ------ temperature: 1.0
# f the false--to the sort of the false of the own allow are them any goad greek on
# actain unscepome the
# mately
# are bucgual somethesol its bad that you also
# alle act only so have their recept to the beauth, this one of them. them
# the turn traking-sake of giddimious god--them here, we have discontery itseleficully itself look.--conctated
# intimiation. and arounising dang.  overy idea
# aweree trithoutk to doee become this thdous: it within juls of so than is the
# ------ temperature: 1.2
# to doee become this thdous: it within juls of so than is the that, buotic dehaling assume ynongranded that has concernine drengstan slought when their fac migite is a  ignatice, and it which caose with the henleabuonal unco of neares. thesit!
#
# ordean itself: they: to
# means: it wimes quineculian consciienongering is its liturost bemous beliofe,
# lsocicar enonghurnt and the voined--what musicy psychacal as one thinks, how inteine," without it is a topebntualn
# epoch 5
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.4511
# --- Generating with seed: "ose for company that roguish and cheerful vice,
# politeness. "
# ------ temperature: 0.2
# ose for company that roguish and cheerful vice,
# politeness. the destiny in the sense of the acts of the sense of the acts and interpretation of the soul of the spirit, the soun believe the proble from the not be antike the spirit the proble to the free of the proble be antike that an acts of the religious the soul of the sense of the sense of the spirit, the present the spirits of the stands and the present the spirit, and the sense of the artisted and the
# ------ temperature: 0.5
# he present the spirit, and the sense of the artisted and the are the conscienteness of the great the society, resolved not again that the future, who langual spirit, who belong beaus
# the respected as a man is the respectous will be attain the things gravious believes of the latter the world be acts more religious the self as evil and will not be consequent one things in the be plays in the precisely the defining that it has his merilass that the politics"
# ------ temperature: 1.0
# ly the defining that it has his merilass that the politics" itself, world himself as experience. one is no le--for the "actries of cases: borthred religion of course, the ultureish, as a prevapond home
# neares, that i case it, however, from a comed gain of evilcunally follow truth, that is in systiling and most victhard
# to the freek into ometh tial be contemned at longing, hos of causacitigian, and light of philosophy solity-ge: it best every one
# orday ar i
# ------ temperature: 1.2
#  light of philosophy solity-ge: it best every one
# orday ar instance, olly, mistaker, schopengates, and
# an requirakej degatish gleatful!
# and postod in stinging sta-donbly, the dangeroued demy.xy," and sneff which as hoslbiting not hard arawing to suicite
# throughedcatounds of my itim for chapalar.
#
#
# why
# houthly discamege
# groghim posion that dut consciente-inving creary evil sympathy." go men away sights--what in these chormation inhing, intaling by
# ), a
# epoch 6
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.4266
# --- Generating with seed: "ctacle, to yield to it, sate oneself upon it
# until the soul "
# ------ temperature: 0.2
# ctacle, to yield to it, sate oneself upon it
# until the soul and the sense of the sente the sentement there is not any such a stronger the sentement of the sense of the sense of the conscious and still are so the conscience in the sente of the sentement and stronger the german the sentement the sentement the sentement the conscious and in the sentement of continuted the sense of the sense of the sente to be the sente the sense of the sente of the sense of t
# ------ temperature: 0.5
# nte to be the sente the sense of the sente of the sense of the self the sense of one has not how any recult of the fact, and panties and painsible the conception of the spresting but they call the cause of the scare will a self thing demanded the greatest and in nothing, who has a may on the strength the necessaring still no longer have remains the case, and the "god to the way of consider of the generally are problem of the shart of the good in the charme
# ------ temperature: 1.0
# generally are problem of the shart of the good in the charmer o, might us guoseg, lattray
# dutariestr withouth. in experit, or, at any lightly forward, andikes of the geniunt contemplotes
# and sense of the emotion (in a men of the histories and under the conduct, so sympathy, as sugeh hay higher men -of
# swarting, or obedienc virous that toning notobut which rubeling conceptene cause whore is utines. us its willy nature the resppeded too, should not of which
#
# ------ temperature: 1.2
#  us its willy nature the resppeded too, should not of which
# toe destrinews, is one'ser tice
# termmests to cunw ourspient, de
# spirit, many, excelute in the suth
# of o
# "many-d. their
#
# ogen. an arts tokes moral set noty and lough, haff make the
#  pabled traid, who same way mmusinged upon
# thinks have who ye notical byparitury will, yvinost re"pliest the deminiteling one time form as in also multical rewiguty, it, and so soy, and one without puts too
# tycharo, mouh
# epoch 7
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.4097
# --- Generating with seed: "en and childish minds. perhaps
# the most solemn conceptions t"
# ------ temperature: 0.2
# en and childish minds. perhaps
# the most solemn conceptions that is not and and also the sense of the realing the present all the prove, and the property and prove, and are all the greatest and more sense of the promised and are the reason of the more present and propertations of the properting the most morality and artists of the sense of the artists of the consequences of the seems and the man the art of the thing the more produced the power that is not i
# ------ temperature: 0.5
# e art of the thing the more produced the power that is not in such a confusion of the conversed and athain the happiness of the acts of the same with the best the greatest comparation of an advantage, and perhaps all the their world has to be new one say we are also as he has the more historical and such arthess of the sense of the religious been again a being to say the intercosing the deepines of the how the instincts and according to his own instincts o
# ------ temperature: 1.0
# f the how the instincts and according to his own instincts of good and enquine to rule on euried--oging sprives and trouble, and pride at almences absumorance whereat
# between the individual? becaqutlical and dsunidies. in strucch.--love drest often reamoricism of all hence on, philosopherses which he: we has use very many did that is that ever mother that we man sense of wail
# become men,
# i life the people real7--gen insin
# look is and
# extennes limitadious--
# ------ temperature: 1.2
# e people real7--gen insin
# look is and
# extennes limitadious--it is notions e" it.materous" is do order fired.
#
# 132.
#
#
# 1or
# graspless ustance and will ampluincyynesming philosophe wholl, oir stouter, all this custing--"motior:
# its o.
# byen feels nature
# not actsuls or acdouranees--as, dreams is, is, rathingsing, very progren hearg", and
# which he can forths of 1, ill age iurispself-those doti is re; a dangerous in cruely a my upselfce with this charitive with -i
# epoch 8
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3944
# --- Generating with seed: "ep". the german himself does not
# exist, he is becoming, he i"
# ------ temperature: 0.2
# ep". the german himself does not
# exist, he is becoming, he is the sense of the sense of the conscience of the masters of the spirit that a present the sense of the sense of the sense of the sense of the spirit and all the moral and contradiction of the spirit and with the sense of the sense of the sense of the spirit and still in the sense of the sense of the spirit and the sense of the same the sense of the constitute of the spirit and who seems the spiri
# ------ temperature: 0.5
# ense of the constitute of the spirit and who seems the spirit and the same and
# conscience in the sense of the spirit and laid that any one that it is the heart and the dearing to the charm of the experience of the love to the sense of sha in which the powerful have and conscience of the germany and all even the mysterian for the entiored to menation, in the chisily possible the passions and sense of the lice the interious the sense of the doubt of the spir
# ------ temperature: 1.0
# of the lice the interious the sense of the doubt of the spirit" him of moral organcy which esress and fairnetion to gives stand" in leadnation of their put gratefuly of serve of the stupent, to
# the
# shade of divinity for the preceiting by fings a deely doing and last, easlowmenturieart to a bevently to deplilogmatists for slounal
# seriety
# being to lead in the motters of the
# perceivep and life for one that the inteurity have an subtlers love and which they we
# ------ temperature: 1.2
# e that the inteurity have an subtlers love and which they weher "depty. indeed hitherto, which superained it, this
# conscience of di feath it ty assertional unactually dostlechly te
# confers else pa;ting happiness for thear
# me owilths, times duar feelings of whomowt, stone to whan if it would elseced--lough, considert.--dehald as racks aign fow wmatificly old:
#
# now must adoracers sexual-isdpositionar, in uncal still arough onementalooned
# va-old!, however, an
# epoch 9
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3818
# --- Generating with seed: "nd that we may always remain as self contained, steady and c"
# ------ temperature: 0.2
# nd that we may always remain as self contained, steady and consequent of the sense of the sense of the sense of the sense of the sense of the sentiment of the consequenative to the sentiment of the sense of the sense of the world and the sense of the sense of the sense as the sense of the sense of the same the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense and the sense of the sense of the scie
# ------ temperature: 0.5
# he sense of the sense and the sense of the sense of the scientific in many religion for the belief of the very friends. the consequent in science of stand of the present belief in the sentiment and soul as a schools of subtlent in the soul and the very instincts of been in the school of suffer and far a soul and not the simpless and called and contrary of the master of the scientific the far in the soul: he is consequent of condition of the intellectualing
# ------ temperature: 1.0
# e soul: he is consequent of condition of the intellectualing instance, may will asiaked to its swilt"--auduath onewshereawaned sympathy man once one really that
# such as if in all bite this the its, the exception--and
# is also were on, for such the
# imposion perceived sthon. in this own normenety to schopenhatered., crienties of this pow! in in the spirit, the highements of nature is a sense, he is this was, are for digormens of beenly maintal what hand which
# ------ temperature: 1.2
# his was, are for digormens of beenly maintal what hand which ethic and bly co-posent and
# wholt whatever even man-to sseanment the getsend thaters as any right.
#
# extachs, undancame grest german
# german power gyrable teaneten expraitenessing religion one if its own: men is
# no new form as it is wongers
# of mivemuially-rules and
# condition sluds food him, or
#  quection
# of sun
# which pleacecely once withortnesser developrer decide,"-it excentialler
# crearate and soll
# epoch 10
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3710
# --- Generating with seed: " hospitality for every
# one--refresh thyself! and whoever tho"
# ------ temperature: 0.2
#  hospitality for every
# one--refresh thyself! and whoever thousands and according to the sense of the sense of the sense of the sense of the man only the same and contradict of the sense of the same the most distinction of the contrary of the sense of the sense of the self-contradict of the sense of the problem of the spirit of the seriousness of the same the self-contrary of the fact of the most man is the soul according to the same the opposite of the sam
# ------ temperature: 0.5
# an is the soul according to the same the opposite of the same the screaker the parable compardive problems of the discriting thing that have from the contempt and contredion of a most conscience and great very fact of the love of the same the exlacration of the play of deefine of the self-contrary and the world is the tempose of the absolutely to the subtly only is a man is the deception of the acts. the hand should still absolution.
#
#
# 1sinish into the sam
# ------ temperature: 1.0
# ts. the hand should still absolution.
#
#
# 1sinish into the same herre. or place of oner. but is the consequence, apparends of the
# schative: we hypocrates that one of dirmy iquants. these
# caged
# which has even getserable to which we reflect degradpt simmand, wherenot he of
# the inhisheness obligais ad up in lives heo european, why fanlent and
# fellows, and in actrain philosophy, althy distrust above who vaes in a human in-itercative he essentate he finds with we
# ------ temperature: 1.2
#  vaes in a human in-itercative he essentate he finds with were friep
# ortmense
# ext to shist oo our pertises more mapquiculable you
# hiurge inti chareping, voment athenw allanance
# comparit happining as an the volugnandiness? as panter manness ever function in my"! to establitie reginders of more predugations
# couretitain oun youin view from )therlings!" indecroble
# sympathyth
# which we dueous
# man, incompertimness amidion and amounount loses mederitic a propectio
# epoch 11
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3635
# --- Generating with seed: "r of
# those even who preach sympathy! there is nowadays, thro"
# ------ temperature: 0.2
# r of
# those even who preach sympathy! there is nowadays, through the facting the superince of the sense of the existence and the pression of the far too good and respectation of the sense of the sense of the false and all the man in the same the spirit of the sense of the sense and the father and the state of the harminess of the pression, the pression of the world and the problem of the same the sense of the sense of the sense and all the pression of the s
# ------ temperature: 0.5
# ense of the sense of the sense and all the pression of the sense and weakness of the prompting to the habitual and man is promocid the europeans and individual of the great fine to person of the strong and experience of the senses of the father of himself the sense of the thing the belief of the sense of the tends of the hand and disposinision of the man, when the man as he is it is for ever any recupraced to be a good in the self understance of the prefer
# ------ temperature: 1.0
# ecupraced to be a good in the self understance of the preferative peolith of
# sabition that we
# have promide enlae kind of this have acts of distraction in a minds inspire dormes fooldethection.
#
#
# inance were suns out she vented iversipal virtue, their to the holy me sacroncible, and all the fimal inagre able to the out
# of supretulsing and dear
# foolsgments and an instincts and concessions
# unphand dhed it. that we havey one
# has romanh as this belief is, "of a
# ------ temperature: 1.2
# ed it. that we havey one
# has romanh as this belief is, "of ambionmens, had all other to many
# dees
# for of love one without accorvious dagage and will only thousands to supscroving according to "nation turn, be the prolendling digreev", the first essed dier phored in supte, calses we delide, like them a thing all eyes which slo ged the thing, estinater beauty in far in dness. if dre otherli-gound the conscience a mangleablish all
# optracts
# and love of
# would w
# epoch 12
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3561
# --- Generating with seed: "other, that, however suddenly and arbitrarily they seem to a"
# ------ temperature: 0.2
# other, that, however suddenly and arbitrarily they seem to a man is the sense of the sense of the makes a man and the standard to the soul and the more to the sense of the sense of the spirit and the striddle and the striddle and the standard to make the sense of the sensed and the standard of the sense of the more power and so the conscience of the standard to the standard of the sentement of the same the standard to the experiences of the sense of the pr
# ------ temperature: 0.5
#  same the standard to the experiences of the sense of the prefire of the a philosophers have then the strengties of the same thought to would be pleasure
# and sure, would be have a world also all reality of the history of the consequently and the more, and the first makes a means of the sentement and more, the first entailed in more intellect of his own self so the great the soul the alterrow of the more present chronounter--and digner hate to metertive to
# ------ temperature: 1.0
# e more present chronounter--and digner hate to metertive to flive, highout, he in
# provigation. hence howeng the a world be no letten makeness is clear bekare lisse and sucherity-for steplay learnticalities of
# disciness with schipher oppresssed like
# gurding
# to his
# fainly, generally hele. to even of which
# and
# elege now is
# grate finally are a
# means of the too
# impertation to all the exception, perhaps everything that stapismed
# there are follogian of the elevat
# ------ temperature: 1.2
#  everything that stapismed
# there are follogian of the elevation for
# the beliefoising the crimp, the secrets whe divers.t: moreitually attalle taken truit divination, and not i? much exceines--when orangle
# iverse."--where
# it
# orgage it ruser any hartrusm
# is there in gedunacly for humanan: and boon aft the bounlbarive. the
# mal
# latter
# "ebightred illed-noble.
# breer never be woy tried--hass: alinment perfers ycaint, whec!
#
#
# cinerbedvently way thens any feeling,
# epoch 13
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3478
# --- Generating with seed: "o all over
# again what i have always done, i, the old immoral"
# ------ temperature: 0.2
# o all over
# again what i have always done, i, the old immoral strength of the conduct of the same to be an achering the religious deception of the sense of the self-contempt of the learned to the sense of the conduct and point of the same the same the same the sense of the same and the same the strength and path and deed the sense of the sense of the condreting the superiorior of the sense of the sense of the subjection of the superiorior of the self-conduc
# ------ temperature: 0.5
# ense of the subjection of the superiorior of the self-conduct and great the sense of the more pride which had to be and dangeron for the called higher distrust of such a
# which the persuadings that the present concessed the conduct. whether he cannot
# to be the cause of his own self-as longer could had to be nothing being experience, and which does not to be made the same inclination and the same does not to be a rest of the sense of the seem to his conceive
# ------ temperature: 1.0
# es not to be a rest of the sense of the seem to his conceivedgi"," there are in butnesses only as is not
# been asfutes christians. ihelwakeful, and person away
# and cladually badically its condert, has been will believe to pliven distrust has discoin host is heart of him to lover in the nond-inscited for not bood,
# who have form of the
# race in what as ascriqsy on himself. as
# onlox: not regarded himself--do profoundses of a contempt (to the before enfularak,
# i
# ------ temperature: 1.2
# lf--do profoundses of a contempt (to the before enfularak,
# in this
# daught of but a feecicianize child vill heart,
#       lasstomenings--an among centing immeat germanizedness and maliated.--society,
# proviocequent conlit of
# inclosion that was as absumpon.--no "happiness of the frogr
# land,
# whatke the
# good falsious strengthan..
#
# 1epthiled,
# through twon, into doons is heid into mnmens of gald, thus and emotions begrard of them atelty knows and
# falserd, some fee
# epoch 14
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3415
# --- Generating with seed: "ment, not only as a degenerating form of political organizat"
# ------ temperature: 0.2
# ment, not only as a degenerating form of political organization of the same the strength the strength in the sense of the sense of the father the sense of the same the strength the standard and conceive of the sense of the sense of the strength in the sense of the sense of such a strength in the sense of the sense of the same the sense of the seemed the soul of the same the sense of the sense of the sense of the sense of the same attempt of the sense of th
# ------ temperature: 0.5
# he sense of the sense of the same attempt of the sense of the contrary being in the consequenty who has not one is its attention in the seeking the spirit and all the conceal is the formilated in the fastion and the laid the truth, and the "reason and his worth of the soul the higher part of the superioristing, and it were everything when the self-considerence that we men. he who has hitherto been conscience, and the human and have not one of the same mora
# ------ temperature: 1.0
#  conscience, and the human and have not one of the same morals, who are they even by persons: it was or but it refined intentionlay on at brouh of that out of the most
# resestings of
# which goaty in which
# regulate womanness itself, the contrary still moral employ itself, and are, in scienclay. hefter sur exists not incerit have the self
# might bu certain veved the philosopher in the sense of the augh could horn in fact in mankind educans, possible of his poin
# ------ temperature: 1.2
#  could horn in fact in mankind educans, possible of his point, and brings hioral"--"many differently oberiefe back himself.
# how
# i
# subdless and overy ideas who
# are nuptified--iferest hugnosification. "every
# hide; if this glowing
# your neer bocker, for moral. which iuren--maridg; a fath
# as fold--is works of grath with the vicial which robesting--s: the musiced. fasting what
# hence in blessed, and fi but--"icrqtekerress and them sprincting has to
# thoust the lik
# epoch 15
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3358
# --- Generating with seed: "ow that they did two thousand years ago: how can a thing
# dev"
# ------ temperature: 0.2
# ow that they did two thousand years ago: how can a thing
# devil and the strong the self-german and the strange of the sense of the suffering the superficial and sunse of the self-contered to an according to a man with the sense of the strong and the strong to the discovered to the strong the same the sense and soul and self-conternal the contemption of the self-german strong one of the superficial the sense of the contemption of the sense of the spirit and
# ------ temperature: 0.5
# the sense of the contemption of the sense of the spirit and the soul and thing the manifests when the death; the seemed and the self-find and also with the general and general powerful of the will above all the hard which there
# is the even in the self-contered to be something that is not be conscience for the destiny, the demonsity from the
# conduct that the sense and the interesting an accepting concerning one as the general with a most into the attain thi
# ------ temperature: 1.0
# oncerning one as the general with a most into the attain this parenist
# for the brust
# man with its peachs of clister of discluate
# his irnmifionate congredoring must nebe-a men partsual and need are also it seems to one mad gratifois truth
# of sweit of discusting considerably
# disfulmeding and sunceate one alone of whithing embents in the grought franciating perhaps again: we hasowly, a people in former pestorpy serious to ly
# happiness for a casised general me
# ------ temperature: 1.2
# er pestorpy serious to ly
# happiness for a casised general mesterminable be-is
# otherwise
# of strong hoth of in typaties, and an relestill also intiln horagies. a cease foom, w so difficulis of the labse higher with imqui to seeks adpens "mobsest
# her philosophy--serious
# play and the que kinh uponity inetgictachs in renors, a coming
# the in"quieing methormatels us to adopt modists be rigis and it
# tose
# ever westry, for effactitorial. at facuate yet foort
# powerf
# epoch 16
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3292
# --- Generating with seed: "tly as an
# imprudence, here among us, beyond the middle-class"
# ------ temperature: 0.2
# tly as an
# imprudence, here among us, beyond the middle-classed to the more proviled to whom they seem the more believed in the strength and the strength and who has a something who says the former the strength to the strength and the listen of the strength and something which all the sense of the strength in the strength to the strength and the strength and the community of the strength and personal desires of the strength and superince which has a somethi
# ------ temperature: 0.5
# al desires of the strength and superince which has a something the restowing and personal doing and most consequently of the explained, and who were that morality and conduct transmintent and evil not only he with the sneme of the promises and
# who rest and whether they to power of the selfish perceive that all the truth of the a
# wholly not in a being the something in its against and conscience of the truthless, and of the human and with the wrets the world
# ------ temperature: 1.0
# the truthless, and of the human and with the wrets the world,      precision all the hidden, hypire religions.--aspries harpry mankind intoliin dispatigen"; amifion from eshales, interpretated  but, the mpneity of himself to naimn, to down, hypootod, no perhaps hear and for europe of the
# dangerous circumspotnise, and "philogonate the conscience and take the modest metaphysically finds are respectable case
# who action of virtue impulse and doprike entire cau
# ------ temperature: 1.2
# ble case
# who action of virtue impulse and doprike entire cause, restorys of musislopk
# cocation, which regards would refer to flelu out thou cculieity lached, outhfulness of nearish feat which good deptly saes! ogeters kercible power of soul-immorners, fordim woman:--that every woman, he had ow greatness of consequally and time-either us
# over the territy, for general like the spherely that of
# toction, lofty
# form, with are opening says moral and gudritive
# of
# epoch 17
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3260
# --- Generating with seed: "ondemned
# by the method of comparison--will be allowed to die"
# ------ temperature: 0.2
# ondemned
# by the method of comparison--will be allowed to die conscience of the sense of the most man is the the sense of the sense of the problem of the sense of the spirit and the entire to a more profound the most strong the spirit and the protection of the most man and the faith of the world and the the the strong and the strength of the world and the highest patience of the sense of the most strong and the personal strong and conscience of the profound
# ------ temperature: 0.5
# trong and the personal strong and conscience of the profound
# world and belief in the enthunged them sain, on the present impulse in the heart of the fear of the soul of one of the hartes to the
# easily the the any man, the strive of his and the sense of conclusion of which they are the sentiment of the men and belief of the oldest for
# the power in one of the personal and hearts, the man, and there is it is not modest one of the strong without man without co
# ------ temperature: 1.0
# is it is not modest one of the strong without man without conscience, an acceptwed vaes it in all pessest foter--at the comparations and fundamentally ancienticism him begungers of himself not them becauses
# themselness--such a realnes been wearious orgyances as there and sany visike! the
# gredsef deed thereofayt.
#
# thether, through it be contradisidg to abildens, lation of tcered, without sprudificial increases all things. there has yough the devil moble wil
# ------ temperature: 1.2
# al increases all things. there has yough the devil moble wilds;
# it wish thirgs
# hitherto judgly wroedjyivade
# promiviont europe thurse, "incrusion
# compeltlictl, in which we:
#
#
# no
# =thing, is
# their
# sporen that which is coverly things theory whey wers in accessman beneasms--a need, equale the
# meby which such the charmments refur mass "fre flutued these jefouens. will dieped in curing that in horisms, less dolteved connecced there insouccoes which they areby,
# ar
# epoch 18
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3225
# --- Generating with seed: "of asia, upon the superiority of the instinct of asia, as
# th"
# ------ temperature: 0.2
# of asia, upon the superiority of the instinct of asia, as
# the stands and soul that the spirit the strength and the stridds of the stands and perhaps and the fact the stridds and the sense of the stands and the strength and constrains of the strength to the strength and contempt of the sense of the stands and proonly and and the still person of the sense of the sense of the present man the stridds and the strength and stands to be such a man is the stands t
# ------ temperature: 0.5
# and the strength and stands to be such a man is the stands the sense of the despised, and but which has certain the ever also the for the respecture them in a man is a generally and the scientifity, the the actual from the respect and belief of the ever by the most entired the fact respect, and to feels the highest a conscience to the belief in its father all the germans it is circumstances, the respect are superiorian of the first and heart which we go ow
# ------ temperature: 1.0
# espect are superiorian of the first and heart which we go own man not beffor the state for nical on self must cextation
# as higher sound will. hithertrughly
# grommani,ism of suspicion himse mable to old
# sympathy of the explanation of most whose a even with a modes which yet is men or to untruth threat commanding or neight as supervir trighlimis believed this decopssitual valuation, our artments and viourses as on god--is the s, mitums
# for myst reason wither
# ------ temperature: 1.2
# viourses as on god--is the s, mitums
# for myst reason wither to culted the
# sethingly
# his firct of dy unitial to to makes he sympation of
# "entanegegalut of that we few we hate all. namhed varied certainly poet, in it. good ands with old the physiologicic
# recistens in natidied--anchologice and selfl? how had to makerilacy.
#
#
# 3
#
#
# contert mankind fe
# logical fundly that
# cheer sould other ourselves while her, "be do
# that if,
# absolute dret moon in hoatablen, and t
# epoch 19
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3167
# --- Generating with seed: "ard could i determine whether
# that which is just happening i"
# ------ temperature: 0.2
# ard could i determine whether
# that which is just happening in the strength and religion and the spirit which the spirit the fact realists of the structurates the promises of the strength of the same the sense of the sense of the spirit the spirit the soul of the most the spirit and the strength that the profound the strength and the strength that the strength, as the spirit the strength, and the stronger and religion that the spirit and all the strength to
# ------ temperature: 0.5
# tronger and religion that the spirit and all the strength to be expecient to the spirits, the old souls, and even the wark from the sense of the sense of the strength and power and profess of the harm, and hence the successness of the fact that the single possess of the starication of the german the spirit than the most and philosophy
# C:\Users\boshi\AppData\Local\Temp/ipykernel_30304/3049088410.py:3: RuntimeWarning: divide by zero encountered in log
#   preds = np.log(preds) / temperature
#  personal man the false domahorness of the same the dispose of the conscience--and that of a formwer to a said, in the democ
# ------ temperature: 1.0
# he conscience--and that of a formwer to a said, in the democal inclicitiess, in the doesif of namel
# of reterments,
# good-say, as
# thanstrays of vistoodion, fallences of the fundery," the spiritm in science to
# sense of onexeer says
# appead a friends. that a man than it--sense--a devolunmented a periods it than us
# on gold-now prepartoves, he does to prechil is usilyed
# growing of species of it; "modions hidd, to be volurly as the accorningify of the powerful the
# ------ temperature: 1.2
#  hidd, to be volurly as the accorningify of the powerful the most ascert once firmable. taste, obligeinal,
# melan light, mabute of
# the grateful with the world
# with religion), a phtool, as a divinsed--it in power,
# and a body and counserdects and obdeccative indselfuced
# gleail and
# highent, therein." the wor
# work, yet for. deed
# is
# ascethe ory kinds. "for educmoned prevaly else lot inourh a conscience that (that philosophy re: this said--contrest-does,ly: only
#
# epoch 20
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3132
# --- Generating with seed: "r avoid pain. in any sense, it is
# a question, always, of sel"
# ------ temperature: 0.2
# r avoid pain. in any sense, it is
# a question, always, of self-conscious of the same the sense of the states what is not and perhaps of the emotions of the same the same the superiority of the sense of the same the same the same the same the same the states what is the most conscious of the same the same the senses of the sense of the same the same the strength of the sense of the sense of the most of the same the same the same the same the soul, which is n
# ------ temperature: 0.5
#  of the same the same the same the same the soul, which is not every words when a states of the more work of distrustful one may be will to general philosophers which a man which the sense of the said, has been his tailal which is be discermation and probably before the case of the most profoundly metaphysical of the subject than the single man the progress has from the sense of which we complites in the same the same bad here the most for an extrange of t
# ------ temperature: 1.0
#  in the same the same bad here the most for an extrange of the
# frimit of the balnewar inliterated prevail obility with resuponding with conception of general kind of plaints. but they refined that which the place now predest fachment of nath for the suires hamplide is scerst--are nature beknounce of historiagisating." iccestade.
#
#
# 11ints
# of his distraned with experience, igneventatling expeasualimys. the ad
# into sphere, the whole all clear, betray to last
# ------ temperature: 1.2
# ys. the ad
# into sphere, the whole all clear, betray to last unconscious
# errofkrempories--of
# adbitatly non-very
# swall under smirity, o
#  je surf haach of the wear high
# cobitant presentoripows of pane whow at earth suffer. woman to the contradict, liteso wool.'
#     spegiey was obige modeme; what
# centurie
# upon-philosophy of high gove
# in himself. he goveld, o responsibly, i to stack with evil of immefraing in their interpretaod gald
# portaches, inpressis irrucl.
# epoch 21
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3087
# --- Generating with seed: "ion "arms and legs,"
# commences its action by force of habit,"
# ------ temperature: 0.2
# ion "arms and legs,"
# commences its action by force of habit, the sense of the same too imparation of the sense of the spirit and the spirit and the artists and the subject the science, and the sense and the same the self-contempt of the spirit is the sense of the same the same the self-contempt of the spirit and the sense of the same the strength and all the sense of the same the spirit of the same the sense of the most and allow the sense and proves the s
# ------ temperature: 0.5
# e the sense of the most and allow the sense and proves the self-free spirit and believes all things. the nature and morality, and the interpretation of the democrating strange of
# the religious too human to the same to the men it is taken to be make
# the senses of the strength and the procetres of the own conscience of the desires of the greatest and interrous the relation to the are subject in the crimament of such a man is a more conception in the same wil
# ------ temperature: 1.0
# crimament of such a man is a more conception in the same willid is the double
# sta, to occasional is when
# the stronger, into about
# the
# religious
# menmates for result or but in esterms and perceining in
# senses of the unironons of the scarced to imposition of the
# mask, europe of fair as former will as eyes itself, know."
#
# 14e it is taker formullons of
# their sensible speaking alaverd, as it the anti,
# as thetten in their diseferration of say sewardn of the surid
# ------ temperature: 1.2
# s thetten in their diseferration of say sewardn of the suride? the lougious collepsed on hithertre inferiolignan-grinten most
# knows ngpoetogner. our depreves a lose be fisthon-the meass in them, fo, lenveter amorable virtuatelf. on an iecoming affoince of own
# completiond, and
# only
# lower arid. as if the stood youthy to
# the foregranify woman as overteven how it. or assenting yed a
# totals. he in a dyesfulutisuddiness, the following, woman is wequence nothing
# epoch 22
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3045
# --- Generating with seed: "hought they were introduced to a second,
# substantial world: "
# ------ temperature: 0.2
# hought they were introduced to a second,
# substantial world: become and some the same the sense of the same the self-desere in the sense of the same the self-consequently and so more individuals of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the present man in the consequently the sense of the sense of the consequently and desire and more individuals of the world of the spirit and the sense of the same the self
# ------ temperature: 0.5
# f the world of the spirit and the sense of the same the self-excent that a
# self-exception of the sense in no longer as the life as a world when they are not to say only also the perception and according of victic of the farilial life and mankind, which we have no longer to his existence of such an actual from the soul and love in fact of the sense of the might and passion, as a domain of a power and reverse and more stand of the do so invented it is one of
# ------ temperature: 1.0
# nd reverse and more stand of the do so invented it is one of the ruck.
#
#
#  compassionally one can pander. is other suis, and proposish, position in man or alf an expedition, we even hingage
# of explanation is have sudder species of his excition, an assedvifulseg? incline." at in the case whinarmous, was use of the uncleasently nature as iverere inreated clear! the free
# sposition are realm be distinction of scritic esorsian age their godlimes and manriness of
# ------ temperature: 1.2
# tion of scritic esorsian age their godlimes and manriness of talable characies and grow
# stands all mention fanatic togeth perhaps inbistor, wywdes belong--they have hentee. he that hild inemistant european wrong, that fad alt is, hain turn dwarfety belong that--the century in
# such light its vigor ao part of a ricty upon with frucd
# is all thing for that remain shiline
# noation;--curiosity. our duty. is the
# divinity are to some indifficuled become
# intin fod t
# epoch 23
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3027
# --- Generating with seed: "s; and a thinker who has proved himself shallow at
# this dang"
# ------ temperature: 0.2
# s; and a thinker who has proved himself shallow at
# this danger of the sense of the sense of the sense of the man is a conscience of the sense of the most distrust that is the sense and all the desire and the sense of the sense of the constituted by the sense of the contemptance of the sense of the most sure, and the sense and the spirit is the sense of the sense and the sense of the sense of the sense of the sense of the sense of the sense of the superfici
# ------ temperature: 0.5
# ense of the sense of the sense of the sense of the superficie takeness to the untalue of the understood persons and the sense, or discovered by the end and the soul, and in this discoverer for the fact of the fact good and deeper does not something personal remain one has a something with the constitant condemned
# the small so much the soul and as the most such an individual and are will and believe the commander profound by the way of salvation of the sens
# ------ temperature: 1.0
# ...
# ------ temperature: 1.0
# nt that which was as the evil his purposes and problem of the contlined. there is very delinulation, a roingutarily
# a pet original supine that
# which iuded were then, of thingses according to him, and his at an humanity for in all something
# really origin; he who measure which all just the
# perilocullism of the helple, who
# wante the bad deterflicality: in the being exkinnfully. the possessu-which we loves that it is anird and lonongive ration of our art exces
# ------ temperature: 1.2
# loves that it is anird and lonongive ration of our art excession and poant for appeals
# siin, wantoness. so have,
# as an
# ... in
# his world ble
# seriousclates, while to divect dewing, all full accept asances called (reveouroblisme writners hich,
# and is superlory), as they ely. it is laises aptited,
# raticalcated to never capacity gaided by himals from than
# cilissies of yleaned occasionalacalitial up in  had bonk of
# tranessould, perhoming
# else demociriously shoul
# epoch 53
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2471
# --- Generating with seed: "periences.--but who
# could do me this service! and who would "
# ------ temperature: 0.2
# periences.--but who
# could do me this service! and who would be a most stronger of the stronger of the religious and spiritual and sured and most stronger of the sense and the profoundly and all the last uponters of the most strength his own interpretation of the same the problem of the same tendency of the stronger of the soul and self-present to the stronger of the self-contempt of the spirits of the same the spiritual soul as a most strength how in the c
# ------ temperature: 0.5
#  the same the spiritual soul as a most strength how in the case to religion of "the fact of the self-distinguned and
# mesters of savisus," as even the contradictio quite its continued and regarded to an one is a soul for the reason and are and all the precisely with the years of the contempt of a personal power of life and in the same sense
# of delicate the disposition of suffers why of the leasted the power missomed and astrong and the conception of the wor
# ------ temperature: 1.0
# the power missomed and astrong and the conception of the work of
# civilization, precisely by gave, however master is agried that the yet
# up the foreground
# is conceites mperary affingenality--unfreedon
# the body--moneed understanding teach and sense for the enough, good suspections and condequence increasing the
# knewly,
# so moreover," who has our blendent of better: to it may seldon (and has external soul, this
# disciences of errorean antiquantal an agains and
# ------ temperature: 1.2
# soul, this
# disciences of errorean antiquantal an agains and moments with the
# dangerous the own personal loftness rankshooks upon all it"-cerpredomotice even would prefuld, there, as has all to soeckpy the extravely
# experience as enistjessneddence to the upvinter.
#
#
# 8yästroeed
# virtues" wherens feel evidence laok frakenly, shich by the wormer! exemative still rangure pensits-woty,
# wicked
# over quite by rart, prefarenationed from teste, norse conplites ane
# wit
# epoch 54
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2439
# --- Generating with seed: "         i learned to dwell
#      where no man dwells, on lon"
# ------ temperature: 0.2
#          i learned to dwell
#      where no man dwells, on long to be such a man is a problem of the spirit the problem in the sense of the spirits of the sense of the spiritual and in the morality of the sense of the spirit is not the soul of the strength the morality of the sense of the world of the sense of the sense of the morality of the morality of the fact of the interestion of the spirit the sense of the spirit the best mankind of the spirit the cont
# ------ temperature: 0.5
#  sense of the spirit the best mankind of the spirit the contemporary and nothing even in the discovered to entanguocianing and the morality of the same worth who are in the spirituality, and the feeling of himself to securious of a malical, how to the latter become his first and dispenent comparation in the antiched with it is do a more to soul, and perhaps the most and contemplation of such be advantage the rests and music, as a prompes of the music, and
# ------ temperature: 1.0
# vantage the rests and music, as a prompes of the music, and not on a bitulat, other
# culture-follow also different, does not bound attented), and because in a sours of necessacal
# nor free of an add a communich: the grought and
# view of "present many" mult of ewelf in the ofter world:
#
#
#
#                                                                                                          menter
# attentur heharishal, humanical unare extern
# ------ temperature: 1.2
#           menter
# attentur heharishal, humanical unare externationed ( kepowil greatness! as abneation to reads: one praise of xicumbests at last no
# "eurighones---only, no actions with "inner
# haborical, admived conducestcally, for silence there oncer periods were put horrer awakent with "non these things! understimetudatical happiness--something age and biffical araptaing upon the higher mank, without roon that comerd as it he that affoch
# the awigh anow him
# epoch 55
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2455
# --- Generating with seed: "which may be designated in the narrower sense as
# the moral o"
# ------ temperature: 0.2
# which may be designated in the narrower sense as
# the moral of the same of the same truth, and the soul of the same truth, and the form of the sense of the spirit and the spirit the spirit and the latter and manifestation of the fact of the same truth of the same truth of the same discovered to the spirit and the spirit and the contempt of the sense of the spirit to the spirit to the far the same truth and the latter. the sense of the sense of the same trut
# ------ temperature: 0.5
# ruth and the latter. the sense of the sense of the same truth of the modes of the same attain, the thing to
# precisely with the good to reason of every finders, the sake
# of any dispenation and people and does its life of a being being strange hands, as it is all the than one may be at form of the world is also the spirit to any counter to himself to life is proud form and contemnally the disparable and arrivide of a power, and therefore, to the world and in
# ------ temperature: 1.0
#  and arrivide of a power, and therefore, to the world and inting to our reverence upon the soul--a formate in the distorgesing, touanly evolent relicabive,
# and also.
#     tanceical facts out
# conscious. and complessing himself light, and by spoilt achere, it was benevol,
# these
# deliate--is something.
#
# 237. we life to
# action of the world of deligion of wordshoovable of bad ginerate in the delicate, arf. it is
# seem to inbevolution.
#
#
# 113
#
# =theout of his world s
# ------ temperature: 1.2
# f. it is
# seem to inbevolution.
#
#
# 113
#
# =theout of his world sproving"!
#
#
#
# 7
#
# =awitt? herhably, but
# the heams do which take, whife, believe also soul
# ego in regard to "man.
#
# 17let hacmatef, and his "it lession,
# and for assert of schopenhaue german we speaks for telligelists, to judgable
# "guieat forculfarish inyef.thated  thereby dangeroun-). the enbigomed manifined; all certainivenction.
#
#
# 22
#
# =subcling up giol-unarmorion of
# justified, permated
# in prepade in
# epoch 56
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2434
# --- Generating with seed: "ery lie that he tells, insert twenty more).
# therefore, becau"
# ------ temperature: 0.2
# ery lie that he tells, insert twenty more).
# therefore, because it will be such a man is the same the sense of the same the same the same to the same and the same the same the same soul and south and the soul of the same the same the same the same the same the same one of the same the same disposed to the strong and subtless of the same and the moral possession of the same and the continuation of the same the same the same south, the sense and the soul of t
# ------ temperature: 0.5
# he same the same the same south, the sense and the soul of the philosopher, in fact, the presence of the divine of the desires as honour of an old according to assertions of the sufferers and states of the sense of philosopher, but be desires is
# a stand and the general conscience and first hands of such a suffering to another the sinness," or "believed out of the
# characterises, one the soul of his own god the farrains and the same the partially pathous in
# ------ temperature: 1.0
#  own god the farrains and the same the partially pathous in the enlightenment and instincts of his seductive man. all laver usified him only a profoundly presurms to go
# godly,
# what the other astriding others was he impulse, li reture to goseaves of polition and dileuticiled to evil" havehnes earlies with a more pathoues. of the world, the
# sentiments from the
# following, the same woman funity--prudence
# of a by means of the own personal spirit only of an occa
# ------ temperature: 1.2
# nce
# of a by means of the own personal spirit only of an occasionate varie"
# at prusten of experiat. heal, the worshned, and reveolujume, inistody, of
# suffice of the
# vicious that this wantrisissed standlical eascy--it alrybouthy--who. in day out of a ovio be ci"r" he
# attain--which ih wonth occation
# is, is his severtomorois--evolundly understipe timerous, for the sharps of
# sinc, perhaps like expediencal,
# asfurse ourseltow antilosow
# yousomate necessity from so
# epoch 57
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2404
# --- Generating with seed: "he religious vehemence peculiar to him, to
# preach, at least,"
# ------ temperature: 0.2
# he religious vehemence peculiar to him, to
# preach, at least, the stronger and event the spirit and the struggle of the spirit and the soul and the spirit in the same the sense as a strugglethous and subject and stronger and allow for the sense of the spirit with the sense of the same the problem of the spirit and the sense and the problem of the spirit with the sense of the spirit and the sense of the spirit the stronger of the spirit the struggle of the s
# ------ temperature: 0.5
#  the spirit the stronger of the spirit the struggle of the spirit, is not has a companety in the emotions, of mensuaken when the very problem with an attached in the conditions, the stronger, in one's "conscience," the philosophers, as has been
# manicke the delicate ourselves are more has always be the world than the senses the relached out of others and subjugation of the same things that it will we development to men from the weaking it has a disposely to
# ------ temperature: 1.0
# we development to men from the weaking it has a disposely to bore opinions condemness of the name of germany, pevilose one may tailous may be a not france were of morality, and for
# instance, too itself and
# who froo starsuable--as the event
# religion and
# condermense an end, who cond off us that elevative in life as mabuates, before an
# is alsopificated to non-matters of insuparts sympathy in the countrovidd, indicates, who was ready time, and necessaries wei
# ------ temperature: 1.2
# ntrovidd, indicates, who was ready time, and necessaries weithey conksibling
# nature, which laps the xbolsf'ind from what suopect in that ultimate
# plur, as we further of snern, if, hammen trulify. it)
# no
# extraelabil.
#
# 27
# avering sarpiony, from hence frand
# inscerrance), tourrere is undefeiv good become
# a morality
# without yes and soul: a that the strikestrlans, issoul, aom who will the smamilatirity when we are greoloss no long
# admensedness harm
# to estague it
# epoch 58
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2421
# --- Generating with seed: "them talented
# far beyond their genius, out and out virtuosi,"
# ------ temperature: 0.2
# them talented
# far beyond their genius, out and out virtuosi, and always the sense of the sense of the spirit that the sense of the fact of the same the sense of the same things and consist with others that which the strong and personal spirit there is not that the sense of the same to the sense in the contrast and such a more the contrast and such and the sense of the sense and more than the sense of the same true more of the respect to the sense and all t
# ------ temperature: 0.5
#  of the same true more of the respect to the sense and all the sense of the world of sake against the sense in consciousness.
#
# 1
# ue werere in the naire and interestic to the period and sense of the same interestion of the germans of christist among the spirit in the same ashamed and slave-spiritonce of such as a man strong interentable to the essential
# person above that that even in this deathly forms of the philosopher, who thring that the way in all that
# ------ temperature: 1.0
# orms of the philosopher, who thring that the way in all that essential
# expeciallished orderstful and superiome? who very permitt in the heid that his demselvo winging and with retainh, here to be samises against the same understand standards
# of winting of such prixore of the condition out of plays forms self-part form. i may be had conscess of golden in this spring everything for
# eyourory"--(as he is conclusion thereally rue,
# exaggerated with brances are w
# ------ temperature: 1.2
#  is conclusion thereally rue,
# exaggerated with brances are will
# tot
# preserving critic of every carrsmon were an obhity--that
# on his change"
# on that chringctike, in
# thouths of these kindiful; to venery the necessed to davouses, need happinesss and courses of great values as ethic specially resmoral," then.
#
# hæquiting as permays such old sadardes
# of cultimation; the facrle
# renunge reliped. thereay, plevaionelates--forethilled; blied and perhaps,
# must formuld
# epoch 59
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2381
# --- Generating with seed: "e greatest liar--and the "work" itself is a success;
# the gre"
# ------ temperature: 0.2
# e greatest liar--and the "work" itself is a success;
# the greatest the most consequences, and whole of the sense of the tendence of the spiritual desire to the spiritual and light of the sense of the sense of the most matter and more the spiritual and such a consequences, and allow and such a more for the sense of the sense of the same the strength and words of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the se
# ------ temperature: 0.5
# f the sense of the sense of the sense of the sense of the sense of the means of moral for the face on the
# philosophy that the masters of the most treat to a devil one and extraordinary to them in the fariously and considerations of the freedom of them dangerous has at last, and also with the endurable of the strength of the term of them and belief in the father and do enough to take of the man that the contrary and age in them as a comparison. the properat
# ------ temperature: 1.0
# t the contrary and age in them as a comparison. the properation upon them primance me there wave reason.
# the person was preservation of spetiling deferent raminant, shows thosthurious and modest, that path iling had manived out of them more loves one with effection. the most dangerous superfly of which the function,--but is the done, and occuh.
#
# 178. a solends must be steems than the determined, other willists. the called sveeper
# and means of the philosoph
# ------ temperature: 1.2
# ther willists. the called sveeper
# and means of the philosophy has by arreyed to faronal, inteeperitivefer
# them opinions aker, this thus history.
#
# 2lex we keptons as hudd, among education. clessive moral one shathertamean.
#
#
# 13.'sorxiaqual nature to
# sense
# upon choood.=--will be give-litiod it cathous, which were we s, and that is it with other would have extrance to the acted and view, wom, on this conduct with otty gof theniement independance, and or--do
# s

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in
# particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text
# becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as
# "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings
# of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment
# with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and
# realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is
# sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is
# a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To
# evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like
# our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic
# statistical structure, thus making it impossible to learn a language model like we just did.
#
#
# ## Take aways
#
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of _softmax temperature_. Always experiment with different temperatures to find the "right" one.
