# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dropout, Flatten, Dense

# %%
# path to the model weights files.
top_model_weights_path = 'bottleneck_fc_model.h5'
# dimensions of our images.
img_width, img_height = 150, 150

train_data_dir = 'data/train'
validation_data_dir = 'data/validation'
nb_train_samples = 20000
nb_validation_samples = 4000
epochs = 50
batch_size = 16

# build the VGG16 network
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(150,150,3))
print('Model loaded.')

# build a classifier model to put on top of the convolutional model
top_model = Sequential()
top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
top_model.add(Dense(256, activation='relu'))
top_model.add(Dropout(0.5))
top_model.add(Dense(1, activation='sigmoid'))

# note that it is necessary to start with a fully-trained
# classifier, including the top classifier,
# in order to successfully do fine-tuning
top_model.load_weights(top_model_weights_path)

# add the model on top of the convolutional base
# model.add(top_model)
model = Model(inputs=base_model.input, outputs=top_model(base_model.output))

# set the first 15 layers (up to the last conv block)
# to non-trainable (weights will not be updated)
for layer in model.layers[:15]:
    layer.trainable = False

# compile the model with a SGD/momentum optimizer
# and a very slow learning rate.
model.compile(loss='binary_crossentropy',
              optimizer=tf.keras.optimizers.SGD(learning_rate=1e-4, momentum=0.9),
              metrics=['accuracy'])

# prepare data augmentation configuration
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary')

model.summary()
# Out:
# Model loaded.
# Found 20000 images belonging to 2 classes.
# Found 3998 images belonging to 2 classes.
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  sequential_1 (Sequential)   (None, 1)                 2097665
#
# =================================================================
# Total params: 16,812,353
# Trainable params: 9,177,089
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
# fine-tune the model
model.fit(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size,
    verbose=2)


model.save('model_3.h5')  # creates a HDF5 file 'model_3.h5'
# Out:
# Epoch 1/50
# 1250/1250 - 124s - loss: 0.2836 - accuracy: 0.8767 - val_loss: 0.1989 - val_accuracy: 0.9205 - 124s/epoch - 99ms/step
# Epoch 2/50
# 1250/1250 - 103s - loss: 0.1850 - accuracy: 0.9248 - val_loss: 0.1731 - val_accuracy: 0.9252 - 103s/epoch - 83ms/step
# Epoch 3/50
# 1250/1250 - 106s - loss: 0.1547 - accuracy: 0.9383 - val_loss: 0.2034 - val_accuracy: 0.9277 - 106s/epoch - 85ms/step
# Epoch 4/50
# 1250/1250 - 106s - loss: 0.1362 - accuracy: 0.9458 - val_loss: 0.1519 - val_accuracy: 0.9370 - 106s/epoch - 85ms/step
# Epoch 5/50
# 1250/1250 - 105s - loss: 0.1193 - accuracy: 0.9507 - val_loss: 0.1581 - val_accuracy: 0.9417 - 105s/epoch - 84ms/step
# Epoch 6/50
# 1250/1250 - 105s - loss: 0.1013 - accuracy: 0.9589 - val_loss: 0.1961 - val_accuracy: 0.9300 - 105s/epoch - 84ms/step
# Epoch 7/50
# 1250/1250 - 106s - loss: 0.0947 - accuracy: 0.9628 - val_loss: 0.1475 - val_accuracy: 0.9422 - 106s/epoch - 85ms/step
# Epoch 8/50
# 1250/1250 - 106s - loss: 0.0868 - accuracy: 0.9657 - val_loss: 0.1386 - val_accuracy: 0.9492 - 106s/epoch - 85ms/step
# Epoch 9/50
# 1250/1250 - 106s - loss: 0.0768 - accuracy: 0.9705 - val_loss: 0.1513 - val_accuracy: 0.9485 - 106s/epoch - 85ms/step
# Epoch 10/50
# 1250/1250 - 106s - loss: 0.0691 - accuracy: 0.9716 - val_loss: 0.1440 - val_accuracy: 0.9467 - 106s/epoch - 85ms/step
# Epoch 11/50
# 1250/1250 - 107s - loss: 0.0651 - accuracy: 0.9739 - val_loss: 0.1612 - val_accuracy: 0.9460 - 107s/epoch - 85ms/step
# Epoch 12/50
# 1250/1250 - 106s - loss: 0.0609 - accuracy: 0.9778 - val_loss: 0.1580 - val_accuracy: 0.9480 - 106s/epoch - 85ms/step
# Epoch 13/50
# 1250/1250 - 108s - loss: 0.0517 - accuracy: 0.9794 - val_loss: 0.2235 - val_accuracy: 0.9435 - 108s/epoch - 86ms/step
# Epoch 14/50
# 1250/1250 - 107s - loss: 0.0443 - accuracy: 0.9828 - val_loss: 0.1626 - val_accuracy: 0.9517 - 107s/epoch - 86ms/step
# Epoch 15/50
# 1250/1250 - 107s - loss: 0.0450 - accuracy: 0.9833 - val_loss: 0.1776 - val_accuracy: 0.9490 - 107s/epoch - 86ms/step
# Epoch 16/50
# 1250/1250 - 107s - loss: 0.0415 - accuracy: 0.9856 - val_loss: 0.1801 - val_accuracy: 0.9475 - 107s/epoch - 86ms/step
# Epoch 17/50
# 1250/1250 - 107s - loss: 0.0367 - accuracy: 0.9865 - val_loss: 0.2236 - val_accuracy: 0.9505 - 107s/epoch - 85ms/step
# Epoch 18/50
# 1250/1250 - 106s - loss: 0.0326 - accuracy: 0.9886 - val_loss: 0.1958 - val_accuracy: 0.9515 - 106s/epoch - 85ms/step
# Epoch 19/50
# 1250/1250 - 107s - loss: 0.0324 - accuracy: 0.9888 - val_loss: 0.1791 - val_accuracy: 0.9540 - 107s/epoch - 85ms/step
# Epoch 20/50
# 1250/1250 - 104s - loss: 0.0268 - accuracy: 0.9901 - val_loss: 0.2198 - val_accuracy: 0.9517 - 104s/epoch - 83ms/step
# Epoch 21/50
# 1250/1250 - 106s - loss: 0.0274 - accuracy: 0.9901 - val_loss: 0.2028 - val_accuracy: 0.9522 - 106s/epoch - 85ms/step
# Epoch 22/50
# 1250/1250 - 105s - loss: 0.0247 - accuracy: 0.9912 - val_loss: 0.2216 - val_accuracy: 0.9520 - 105s/epoch - 84ms/step
# Epoch 23/50
# 1250/1250 - 106s - loss: 0.0218 - accuracy: 0.9916 - val_loss: 0.2322 - val_accuracy: 0.9470 - 106s/epoch - 85ms/step
# Epoch 24/50
# 1250/1250 - 104s - loss: 0.0209 - accuracy: 0.9929 - val_loss: 0.2348 - val_accuracy: 0.9535 - 104s/epoch - 83ms/step
# Epoch 25/50
# 1250/1250 - 106s - loss: 0.0205 - accuracy: 0.9920 - val_loss: 0.2287 - val_accuracy: 0.9507 - 106s/epoch - 85ms/step
# Epoch 26/50
# 1250/1250 - 104s - loss: 0.0143 - accuracy: 0.9950 - val_loss: 0.2523 - val_accuracy: 0.9507 - 104s/epoch - 83ms/step
# Epoch 27/50
# 1250/1250 - 106s - loss: 0.0135 - accuracy: 0.9952 - val_loss: 0.2434 - val_accuracy: 0.9525 - 106s/epoch - 85ms/step
# Epoch 28/50
# 1250/1250 - 104s - loss: 0.0151 - accuracy: 0.9944 - val_loss: 0.2253 - val_accuracy: 0.9500 - 104s/epoch - 83ms/step
# Epoch 29/50
# 1250/1250 - 106s - loss: 0.0153 - accuracy: 0.9942 - val_loss: 0.2522 - val_accuracy: 0.9495 - 106s/epoch - 85ms/step
# Epoch 30/50
# 1250/1250 - 105s - loss: 0.0183 - accuracy: 0.9937 - val_loss: 0.2087 - val_accuracy: 0.9525 - 105s/epoch - 84ms/step
# Epoch 31/50
# 1250/1250 - 107s - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.2541 - val_accuracy: 0.9552 - 107s/epoch - 85ms/step
# Epoch 32/50
# 1250/1250 - 106s - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.2620 - val_accuracy: 0.9505 - 106s/epoch - 85ms/step
# Epoch 33/50
# 1250/1250 - 107s - loss: 0.0101 - accuracy: 0.9968 - val_loss: 0.2987 - val_accuracy: 0.9505 - 107s/epoch - 86ms/step
# Epoch 34/50
# 1250/1250 - 106s - loss: 0.0099 - accuracy: 0.9970 - val_loss: 0.3059 - val_accuracy: 0.9465 - 106s/epoch - 85ms/step
# Epoch 35/50
# 1250/1250 - 106s - loss: 0.0102 - accuracy: 0.9965 - val_loss: 0.2659 - val_accuracy: 0.9532 - 106s/epoch - 85ms/step
# Epoch 36/50
# 1250/1250 - 108s - loss: 0.0111 - accuracy: 0.9964 - val_loss: 0.2625 - val_accuracy: 0.9547 - 108s/epoch - 86ms/step
# Epoch 37/50
# 1250/1250 - 107s - loss: 0.0120 - accuracy: 0.9960 - val_loss: 0.2621 - val_accuracy: 0.9530 - 107s/epoch - 85ms/step
# Epoch 38/50
# 1250/1250 - 106s - loss: 0.0096 - accuracy: 0.9969 - val_loss: 0.2404 - val_accuracy: 0.9530 - 106s/epoch - 85ms/step
# Epoch 39/50
# 1250/1250 - 107s - loss: 0.0087 - accuracy: 0.9969 - val_loss: 0.2848 - val_accuracy: 0.9522 - 107s/epoch - 86ms/step
# Epoch 40/50
# 1250/1250 - 107s - loss: 0.0086 - accuracy: 0.9971 - val_loss: 0.2606 - val_accuracy: 0.9545 - 107s/epoch - 86ms/step
# Epoch 41/50
# 1250/1250 - 108s - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.2714 - val_accuracy: 0.9547 - 108s/epoch - 87ms/step
# Epoch 42/50
# 1250/1250 - 108s - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.3022 - val_accuracy: 0.9507 - 108s/epoch - 86ms/step
# Epoch 43/50
# 1250/1250 - 109s - loss: 0.0068 - accuracy: 0.9978 - val_loss: 0.2993 - val_accuracy: 0.9530 - 109s/epoch - 87ms/step
# Epoch 44/50
# 1250/1250 - 107s - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.2721 - val_accuracy: 0.9515 - 107s/epoch - 86ms/step
# Epoch 45/50
# 1250/1250 - 107s - loss: 0.0057 - accuracy: 0.9977 - val_loss: 0.3001 - val_accuracy: 0.9530 - 107s/epoch - 85ms/step
# Epoch 46/50
# 1250/1250 - 105s - loss: 0.0077 - accuracy: 0.9977 - val_loss: 0.3074 - val_accuracy: 0.9552 - 105s/epoch - 84ms/step
# Epoch 47/50
# 1250/1250 - 106s - loss: 0.0090 - accuracy: 0.9972 - val_loss: 0.2384 - val_accuracy: 0.9532 - 106s/epoch - 85ms/step
# Epoch 48/50
# 1250/1250 - 104s - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.3081 - val_accuracy: 0.9552 - 104s/epoch - 83ms/step
# Epoch 49/50
# 1250/1250 - 107s - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.3132 - val_accuracy: 0.9512 - 107s/epoch - 86ms/step
# Epoch 50/50
# 1250/1250 - 106s - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.2962 - val_accuracy: 0.9545 - 106s/epoch - 84ms/step
